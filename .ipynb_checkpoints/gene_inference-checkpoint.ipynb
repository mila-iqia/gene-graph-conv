# %%
import data
import data.gene_datasets
import sklearn, sklearn.model_selection, sklearn.metrics, sklearn.linear_model
import numpy as np
import matplotlib, matplotlib.pyplot as plt
import networkx as nx
# Out:
# /u/weissmar/venv/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tcgatissue = data.gene_datasets.TCGATissue()
# Out:
# Converting one-hot labels to integers

# %%
class Object(object):
    pass
opt = Object()
opt.seed = 0
opt.nb_class = None
opt.nb_examples = None
opt.nb_nodes = None
opt.graph = "pathway"
opt.dataset = tcgatissue

# %%
tcgatissue.set_graph(opt)
# Out:
# 'Graph' object has no attribute 'labels'

# %%
plt.imshow(tcgatissue.adj)

# %%
g = nx.from_numpy_matrix(tcgatissue.adj)
mapping = dict(zip(range(0, len(tcgatissue.df.columns)), tcgatissue.df.columns))
g = nx.relabel_nodes(g, mapping)

# %%
def lr(df, labels, trials, samples):
    scores = []
    for i in range(trials):
        X_train, X_test, y_train, y_test = \
        sklearn.model_selection.train_test_split(df[:samples], labels[:samples], stratify=labels[:samples], train_size=0.5, random_state=i)

        model = sklearn.linear_model.LogisticRegression()
        model = model.fit(X_train, y_train)

        score = sklearn.metrics.roc_auc_score(model.predict(X_test),y_test)
        #print score
        scores.append(score)
    #print np.round(np.mean(scores),2),  np.round(np.std(scores),2)
    return np.round(np.mean(scores), 2),  np.round(np.std(scores),2)

# %%
genes_todo = [x for x in g.nodes() if len(list(g.neighbors(x)))>3]

# %%
genes_todo
# Out:
# ['HSPA6',
#  'HSPA5',
#  'B2M',
#  'PIK3CG',
#  'NUP98',
#  'PARP12',
#  'CTBP2',
#  'ITGA2',
#  'ITGA3',
#  'ITGA5',
#  'ITGA7',
#  'APOA4',
#  'GPRASP1',
#  'XPO1',
#  'TTN',
#  'TOP1',
#  'ITGAM',
#  'FOXC2',
#  'GANAB',
#  'SMAD9',
#  'LRPAP1',
#  'SMAD7',
#  'SPARC',
#  'SH2B3',
#  'PIPOX',
#  'SPP1',
#  'ATP1A1',
#  'EEF1A2',
#  'FYCO1',
#  'HOMER1',
#  'CD44',
#  'CFH',
#  'CFB',
#  'PRL',
#  'RELN',
#  'HMG20B',
#  'TBL2',
#  'UQCRC2',
#  'PAK1',
#  'KHDRBS2',
#  'MED8',
#  'MYCN',
#  'IGF1',
#  'TCF3',
#  'NUDT4',
#  'IGFBP2',
#  'IGFBP3',
#  'IGFBP5',
#  'EPS8L2',
#  'GAS8',
#  'MEF2A',
#  'MEF2D',
#  'AMPD3',
#  'TEX11',
#  'PRKAR2B',
#  'CFLAR',
#  'TRADD',
#  'UBE2D4',
#  'ETFA',
#  'CLIC1',
#  'ATXN2L',
#  'PRDX2',
#  'PRDX1',
#  'AP3S1',
#  'FCGR2B',
#  'FCGR2A',
#  'SKIL',
#  'AP2A2',
#  'NSUN5',
#  'TUBG2',
#  'B3GAT3',
#  'CACNA1I',
#  'CALM1',
#  'CUL2',
#  'TRIM21',
#  'SLC25A5',
#  'GNPAT',
#  'KIF5B',
#  'CSF2RB',
#  'NDRG1',
#  'EGR1',
#  'ZYX',
#  'SLA',
#  'RAD50',
#  'PTPN9',
#  'MYO1C',
#  'RPS3',
#  'RPS2',
#  'PPBP',
#  'OBSL1',
#  'PDHA2',
#  'LGALS1',
#  'CP',
#  'MYC',
#  'FSCN1',
#  'CSNK2B',
#  'NMI',
#  'PLAUR',
#  'LOX',
#  'RPL22',
#  'IL1RAP',
#  'COL6A1',
#  'DENND3',
#  'DDIT3',
#  'IFI35',
#  'SRPR',
#  'SOCS3',
#  'EEF1G',
#  'EEF1D',
#  'RPL4',
#  'RPL5',
#  'CD151',
#  'ATP5C1',
#  'CHD7',
#  'NPC1',
#  'IL4R',
#  'RCN1',
#  'ANKRD26',
#  'SPI1',
#  'ITPR1',
#  'PLSCR1',
#  'VLDLR',
#  'RNF128',
#  'FCER1G',
#  'RPL3',
#  'HIST1H1E',
#  'BRWD1',
#  'SOS2',
#  'PSMB8',
#  'MLH3',
#  'TRAF1',
#  'AP4M1',
#  'RSU1',
#  'SLC2A3',
#  'IL6ST',
#  'CAMK2A',
#  'TEX2',
#  'HSP90B1',
#  'JAK2',
#  'GRM1',
#  'PPARA',
#  'CD14',
#  'VSNL1',
#  'SPHK1',
#  'RAP1A',
#  'CAPG',
#  'PTX3',
#  'DDB2',
#  'MCAT',
#  'LMO2',
#  'ERBB2',
#  'WRNIP1',
#  'PLCG2',
#  'MYOD1',
#  'PSMC2',
#  'SEC61G',
#  'TWIST1',
#  'FCGR1A',
#  'CDKN2A',
#  'SMPDL3A',
#  'PHGDH',
#  'SAP30L',
#  'TIAL1',
#  'ANGPT2',
#  'RRBP1',
#  'ANGPT1',
#  'COPB1',
#  'F10',
#  'PSMB10',
#  'SMPD1',
#  'SMPD3',
#  'FLT4',
#  'FANCF',
#  'H1F0',
#  'EXOC3',
#  'ENO1',
#  'CLU',
#  'AMOTL2',
#  'PHB2',
#  'LIMS1',
#  'TSHR',
#  'SORBS2',
#  'INPPL1',
#  'SUPT3H',
#  'PRKCD',
#  'LMNA',
#  'TBX21',
#  'ATF7IP',
#  'CTSB',
#  'CTSD',
#  'RPL10',
#  'RPL12',
#  'RPL13',
#  'FGFR3',
#  'FGFR1',
#  'EPB41',
#  'UBE2I',
#  'STX1A',
#  'KRT1',
#  'IL1B',
#  'DACT1',
#  'CAST',
#  'SLC43A3',
#  'IL5',
#  'BIRC3',
#  'EIF5',
#  'ANXA1',
#  'ANXA2',
#  'SQSTM1',
#  'POGZ',
#  'C1S',
#  'ILF2',
#  'TIMP1',
#  'EPO',
#  'CHMP2A',
#  'LYN',
#  'TLR2',
#  'DDX6',
#  'TLR1',
#  'MYO15B',
#  'RPS27L',
#  'UPF2',
#  'RNH1',
#  'TNR',
#  'MYD88',
#  'EHMT2',
#  'VAV1',
#  'SDC2',
#  'PDZD2',
#  'HEYL',
#  'MAPK8',
#  'RBL2',
#  'GLB1',
#  'STAT5A',
#  'FBL',
#  'DGKZ',
#  'SERPINA1',
#  'SERPINA3',
#  'PLOD2',
#  'GNA14',
#  'PXN',
#  'RAD21',
#  'SNRPA',
#  'ANP32B',
#  'SQRDL',
#  'IQCE',
#  'DDX41',
#  'CDKN1A',
#  'IL6',
#  'APOD',
#  'NF1',
#  'IL5RA',
#  'BLM',
#  'SDF4',
#  'BLK',
#  'HCK',
#  'FLOT1',
#  'MYH14',
#  'NEDD9',
#  'SMC3',
#  'S100A9',
#  'S100A8',
#  'LEF1',
#  'PELO',
#  'CXCR4',
#  'BMI1',
#  'LGALS3BP',
#  'CAMK2B',
#  'RBMX',
#  'TLN2',
#  'PTK2B',
#  'ARHGEF7',
#  'IFITM3',
#  'IFITM2',
#  'LDB1',
#  'TRIP6',
#  'LAMB1',
#  'DDX50',
#  'HSPB1',
#  'BUB3',
#  'MYH7',
#  'RANBP1',
#  'STAB1',
#  'IQGAP1',
#  'CDYL',
#  'ETS1',
#  'CARD10',
#  'ABI1',
#  'TGFBI',
#  'SP100',
#  'MMP2',
#  'ACADVL',
#  'PCCB',
#  'PCCA',
#  'LRRC1',
#  'HRAS',
#  'GRIA1',
#  'GRIA4',
#  'SLC9A7',
#  'MEIS1',
#  'GSN',
#  'PLCB1',
#  'EPHB1',
#  'LAMC1',
#  'IL13RA2',
#  'TOLLIP',
#  'MDFI',
#  'YY1',
#  'RPP30',
#  'A2M',
#  'ATRX',
#  'UCHL1',
#  'FAS',
#  'FAP',
#  'TERT',
#  'GTPBP4',
#  'AP4E1',
#  'CASP4',
#  'CASP3',
#  'CASP1',
#  'CASP9',
#  'BCL3',
#  'OAT',
#  'S100A11',
#  'PHYHIP',
#  'YWHAH',
#  'P4HB',
#  'PCGF2',
#  'DES',
#  'CTR9',
#  'SIRT1',
#  'RNF7',
#  'NCF2',
#  'NCF4',
#  'SDC4',
#  'TBK1',
#  'HSPA12A',
#  'RIN1',
#  'MET',
#  'EMP3',
#  'EMP1',
#  'RPS10',
#  'ARL1',
#  'RIPK1',
#  'RIPK2',
#  'ULK2',
#  'TFAM',
#  'TNC',
#  'SRPK1',
#  'ACTN1',
#  'PTPRC',
#  'IFNAR1',
#  'SGPL1',
#  'TYROBP',
#  'IRAK4',
#  'GATA2',
#  'GATA1',
#  'GRB10',
#  'PRR14',
#  'CSRP1',
#  'TNFSF10',
#  'MX1',
#  'SERPINE1',
#  'ARNTL',
#  'CCT3',
#  'CCT7',
#  'CCT4',
#  'PDLIM4',
#  'GDI2',
#  'CBL',
#  'FLNC',
#  'TNFRSF10B',
#  'DCTN3',
#  'HIC2',
#  'TFPT',
#  'PARVB',
#  'PARVA',
#  'MVP',
#  'LAMA2',
#  'TNFAIP3',
#  'ABCA1',
#  'TUBGCP2',
#  'VAV3',
#  'PSMD9',
#  'PSMD5',
#  'NGFR',
#  'TNFAIP2',
#  'MAD1L1',
#  'AQP1',
#  'SIPA1L3',
#  'ITGB5',
#  'ARIH2',
#  'LCP2',
#  'BACE1',
#  'SUPV3L1',
#  'FGR',
#  'SLC12A2',
#  'RPH3A',
#  'LY96',
#  'C1QA',
#  'ITGB2',
#  'ITGB4',
#  'TUBB2A',
#  'EIF4B',
#  'EFNB2',
#  'HDAC3',
#  'RFC2',
#  'SH3BP2',
#  'MXD1',
#  'CST3',
#  'RAB15',
#  'CSTA',
#  'LAMP2',
#  'NAT10',
#  'RAD52',
#  'ERCC6',
#  'MRPS17',
#  'CEBPB',
#  'CEBPD',
#  'BID',
#  'TPP1',
#  'LSM2',
#  'CTNNA1',
#  'SSR3',
#  'HSF2',
#  'APOC1',
#  'GADD45G',
#  'TFRC',
#  'TAGLN2',
#  'GUSB',
#  'SLC25A24',
#  'YME1L1',
#  'CRK',
#  'ID1',
#  'CR1',
#  'TNFRSF1B',
#  'TNFRSF1A',
#  'CYP19A1',
#  'CD4',
#  'CCR1',
#  'SERPING1',
#  'EHMT1',
#  'ZNF264',
#  'STAT3',
#  'STAT2',
#  'CD81',
#  'HBEGF',
#  'FOSL1',
#  'FOSL2',
#  'BCL7A',
#  'CD63',
#  'LRP1',
#  'PLXNA1',
#  'MAP2K7',
#  'MAP2K4',
#  'NEFL',
#  'SEC31B',
#  'SUV39H2',
#  'SUCLG1',
#  'LPL',
#  'MSR1',
#  'CSNK1E',
#  'CSNK2A2',
#  'GFRA1',
#  'PABPC1',
#  'PABPC3',
#  'DNM1',
#  'EED',
#  'AJAP1',
#  'STOM',
#  'IKZF2',
#  'SHANK1',
#  'FES',
#  'GLUD1',
#  'SREBF1',
#  'ISG20',
#  'KARS',
#  'CD59',
#  'MSN',
#  'DOK1',
#  'LDHA',
#  'LDHB',
#  'PLAT',
#  'GPC4',
#  'PTRF',
#  'SERPINH1']

# %%
for gene in genes_todo:
    df = tcgatissue.df
    labels = [1 if x > df[gene].mean() else 0 for x in df[gene]]
    df = df.drop(gene, axis=1)

    first_degree_neighbors = df.loc[:, list(g.neighbors(gene))].dropna(axis=1)
    full = lr(df, labels, 10, 100)
    first_degree = lr(first_degree_neighbors, labels, 10, 100)
    print gene + " full=" + str(full) + " first_degree=" + str(first_degree) + " diff=" + str(full[0] - first_degree[0])
    if (full[0] - first_degree[0]) < 0:
        print "#####" + gene
# Out:
# /u/weissmar/venv/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)
# HSPA6 full=(0.68, 0.05) first_degree=(0.64, 0.07) diff=0.040000000000000036
# HSPA5 full=(0.61, 0.06) first_degree=(0.67, 0.05) diff=-0.06000000000000005
# B2M full=(0.74, 0.03) first_degree=(0.7, 0.04) diff=0.040000000000000036
# PIK3CG full=(0.85, 0.04) first_degree=(0.87, 0.04) diff=-0.020000000000000018
# NUP98 full=(0.76, 0.04) first_degree=(0.75, 0.04) diff=0.010000000000000009
# PARP12 full=(0.7, 0.05) first_degree=(0.42, 0.05) diff=0.27999999999999997
# CTBP2 full=(0.75, 0.06) first_degree=(0.51, 0.1) diff=0.24
# ITGA2 full=(0.81, 0.03) first_degree=(0.76, 0.06) diff=0.050000000000000044
# ITGA3 full=(0.77, 0.06) first_degree=(0.67, 0.06) diff=0.09999999999999998
# ITGA5 full=(0.72, 0.04) first_degree=(0.66, 0.06) diff=0.05999999999999994
# ITGA7 full=(0.72, 0.04) first_degree=(0.52, 0.08) diff=0.19999999999999996
# APOA4 full=(0.89, 0.06) first_degree=(0.73, 0.07) diff=0.16000000000000003
# GPRASP1 full=(0.86, 0.05) first_degree=(0.55, 0.06) diff=0.30999999999999994
# XPO1 full=(0.71, 0.03) first_degree=(0.75, 0.03) diff=-0.040000000000000036
# TTN full=(0.7, 0.04) first_degree=(0.67, 0.05) diff=0.029999999999999916
# TOP1 full=(0.69, 0.04) first_degree=(0.74, 0.06) diff=-0.050000000000000044
# ITGAM full=(0.84, 0.04) first_degree=(0.76, 0.05) diff=0.07999999999999996
# FOXC2 full=(0.69, 0.08) first_degree=(0.71, 0.06) diff=-0.020000000000000018
# GANAB full=(0.69, 0.05) first_degree=(0.61, 0.04) diff=0.07999999999999996
# SMAD9 full=(0.81, 0.04) first_degree=(0.68, 0.05) diff=0.13
# LRPAP1 full=(0.81, 0.03) first_degree=(0.66, 0.07) diff=0.15000000000000002
# SMAD7 full=(0.75, 0.05) first_degree=(0.66, 0.08) diff=0.08999999999999997
# SPARC full=(0.79, 0.05) first_degree=(0.55, 0.07) diff=0.24
# SH2B3 full=(0.75, 0.06) first_degree=(0.62, 0.05) diff=0.13
# PIPOX full=(0.78, 0.05) first_degree=(0.64, 0.06) diff=0.14
# SPP1 full=(0.73, 0.06) first_degree=(0.64, 0.06) diff=0.08999999999999997
# ATP1A1 full=(0.72, 0.06) first_degree=(0.72, 0.04) diff=0.0
# EEF1A2 full=(0.73, 0.07) first_degree=(0.56, 0.06) diff=0.16999999999999993
# FYCO1 full=(0.79, 0.05) first_degree=(0.58, 0.07) diff=0.21000000000000008
# HOMER1 full=(0.82, 0.03) first_degree=(0.62, 0.07) diff=0.19999999999999996
# CD44 full=(0.73, 0.03) first_degree=(0.68, 0.04) diff=0.04999999999999993
# CFH full=(0.82, 0.04) first_degree=(0.78, 0.04) diff=0.039999999999999925
# CFB full=(0.77, 0.06) first_degree=(0.62, 0.04) diff=0.15000000000000002
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-4a824db719e6> in <module>()
#       5
#       6     first_degree_neighbors = df.loc[:, list(g.neighbors(gene))].dropna(axis=1)
# ----> 7     full = lr(df, labels, 10, 100)
#       8     first_degree = lr(first_degree_neighbors, labels, 10, 100)
#       9     print gene + " full=" + str(full) + " first_degree=" + str(first_degree) + " diff=" + str(full[0] - first_degree[0])
#
# <ipython-input-12-65152921a1d3> in lr(df, labels, trials, samples)
#       7         model = model.fit(X_train, y_train)
#       8
# ----> 9         score = sklearn.metrics.roc_auc_score(model.predict(X_test),y_test)
#      10         #print score
#      11         scores.append(score)
#
# /u/weissmar/venv/lib/python2.7/site-packages/sklearn/metrics/ranking.pyc in roc_auc_score(y_true, y_score, average, sample_weight)
#     275     return _average_binary_score(
#     276         _binary_roc_auc_score, y_true, y_score, average,
# --> 277         sample_weight=sample_weight)
#     278
#     279
#
# /u/weissmar/venv/lib/python2.7/site-packages/sklearn/metrics/base.pyc in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      73
#      74     if y_type == "binary":
# ---> 75         return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      76
#      77     check_consistent_length(y_true, y_score, sample_weight)
#
# /u/weissmar/venv/lib/python2.7/site-packages/sklearn/metrics/ranking.pyc in _binary_roc_auc_score(y_true, y_score, sample_weight)
#     266     def _binary_roc_auc_score(y_true, y_score, sample_weight=None):
#     267         if len(np.unique(y_true)) != 2:
# --> 268             raise ValueError("Only one class present in y_true. ROC AUC score "
#     269                              "is not defined in that case.")
#     270
#
# ValueError: Only one class present in y_true. ROC AUC score is not defined in that case.

# %%
np.where(tcgatissue.df.columns[:] == "EVC")

# %%
dataset.node_names
# Out:
# <HDF5 dataset "gene_names": shape (16300,), type "|S64">

# %%
lr(dataset.df, dataset.labels, 10, 100)

# %%
lr(first_degree_neighbors, dataset.labels, 10, 100)

# %%
dataset.gene_to_infer
scores = []
for i in range(10):
    samples = 100
    first_degree_neighbors = dataset.df.loc[:, list(g.neighbors("CD53"))].dropna(axis=1)
    X_train, X_test, y_train, y_test = \
    sklearn.model_selection.train_test_split(first_degree_neighbors[:samples], dataset.labels[:samples], stratify=dataset.labels[:samples], train_size=0.5, random_state=i)

    model = sklearn.linear_model.LogisticRegression()
    model = model.fit(X_train, y_train)

    score = sklearn.metrics.roc_auc_score(model.predict(X_test),y_test)
    #print score
    scores.append(score)
print np.round(np.mean(scores),2),  np.round(np.std(scores),2)
# Out:
# /u/weissmar/venv/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """
# 0.82 0.04

# %%
list(g.neighbors("REST"))
