# %%
import sys
import time
import copy
from itertools import repeat
import data, data.gene_datasets
import sklearn, sklearn.model_selection, sklearn.metrics, sklearn.linear_model, sklearn.neural_network, sklearn.tree
import numpy as np
import matplotlib, matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import gene_inference, gene_inference.utils
from gene_inference.models import lr, mlp, decision_tree
from gene_inference.infer_genes import infer_gene, infer_all_genes, sample_neighbors
from data.graph import Graph
from models.models import CGN
from data.utils import split_dataset
import optimization as otim
from torch.autograd import Variable
import torch
import tensorflow
from analysis.metrics import record_metrics_for_epoch
from analysis.logger import Logger

# %load_ext autoreload
# %autoreload 2

# Goal: To get a comparison of the methods with CGN and different dropouts today
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
tcgatissue = data.gene_datasets.TCGATissue(data_dir='./genomics/TCGA/', data_file='TCGA_tissue_ppi.hdf5')
class Object(object):
    pass

opt = Object()
opt.seed = 0
opt.nb_class = None
opt.nb_examples = None
opt.nb_nodes = None
opt.graph = "pathway"
opt.dataset = tcgatissue

graph = Graph()
#path = "./genomics/graph/pancan-tissue-graph.hdf5"
path = "./genomics/graph/pancan-tissue-graph.hdf5"
graph.load_graph(path)
#graph.intersection_with(tcgatissue)
g = nx.from_numpy_matrix(graph.adj)
mapping = dict(zip(range(0, len(tcgatissue.df.columns)), tcgatissue.df.columns))
g = nx.relabel_nodes(g, mapping)
# Out:
# Converting one-hot labels to integers

# %%
import models, models.graphLayer
reload(models.graphLayer)
opt.add_self = True
opt.norm_adj = True
opt.num_layer = 2
opt.cuda = False
opt.add_connectivity = True
opt.pool_graph = "ignore"

# %%
adj_transform, aggregate_function = models.graphLayer.get_transform(opt, graph.adj)

# %%
num_channel = 4
num_layer = 1
nb_class = 2
model = CGN(
            nb_nodes=len(tcgatissue.df.columns), 
            input_dim=1,
            channels=[num_channel] * num_layer,
            adj=graph.adj,
            out_dim=nb_class,
            on_cuda=False,
            add_emb=None,
            transform_adj=adj_transform,
            aggregate_adj=aggregate_function,
            use_gate=True,
            dropout=True,
            )
# Out:
# Doing drop-out

# %%
def cgn(dataset, trials, train_size, test_size, penalty=False, num_epochs=100):
    scores = []
    writer = Logger("./")
    labels = torch.LongTensor(dataset.labels)
    criterions = otim.get_criterion(dataset)
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01, weight_decay=0.0001)
    patience = 20
    
    train_ratio = float(train_size) / (2 * test_size + train_size)
    for trial in range(trials):
        train_set, valid_set, test_set = split_dataset(dataset, batch_size=10, random=True, train_ratio=train_ratio, seed=trial, nb_samples=train_size + 2 * test_size, nb_per_class=None)
        max_valid = 0
        for t in range(0, num_epochs):
            start_timer = time.time()
            for no_b, mini in enumerate(train_set):
                inputs, labels = mini['sample'], mini['labels']

                inputs = Variable(inputs, requires_grad=False).float()

                model.train()

                y_pred = model(inputs)

                # Compute and print loss
                crit_loss = otim.compute_loss(criterions, y_pred, labels)
                #model_regularization_loss = model.regularization(opt.model_reg_lambda)
                #l1_loss = setup_l1_loss(my_model, opt.l1_loss_lambda, l1_criterion, opt.cuda)
                #total_loss = crit_loss + model_regularization_loss + l1_loss
                total_loss = crit_loss

                # Zero gradients, perform a backward pass, and update the weights.
                optimizer.zero_grad()
                crit_loss.backward()
                optimizer.step()
                model.eval()
            time_this_epoch = time.time() - start_timer
            acc, auc = record_metrics_for_epoch(writer, crit_loss, total_loss, t, time_this_epoch, train_set, valid_set, test_set, model, dataset, cuda=False)

            summary = [
                t,
                crit_loss.data[0],
                acc['train'],
                acc['valid'],
                auc['train'],
                auc['valid'],
                time_this_epoch
            ]
            summary = "epoch {}, cross_loss: {:.03f}, acc_train: {:0.3f}, acc_valid: {:0.3f}, auc_train: {:0.3f}, auc_valid:{:0.3f}, time: {:.02f} sec".format(*summary)
            print summary

            patience = patience - 1
            if patience == 0:
                break
            if max_valid < auc['valid']:
                max_valid = auc['valid']
            if max_valid > auc['valid'] and t > 7:
                scores.append(auc['valid']) 
                break

    return np.round(np.mean(scores), 2),  np.round(np.std(scores), 2)

# %%
reload(data)
reload(models)
tcgatissue = data.gene_datasets.TCGATissue(data_dir='./genomics/TCGA/', data_file='TCGA_tissue_ppi.hdf5')
cgn_df = infer_gene(cgn, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=False)
lr_df = infer_gene(lr, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=True)
mlp_df = infer_gene(mlp, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=True)
# Out:
# Converting one-hot labels to integers
# epoch 0, cross_loss: 0.575, acc_train: 0.556, acc_valid: 0.510, auc_train: 0.999, auc_valid:0.858, time: 0.89 sec
# epoch 1, cross_loss: 0.311, acc_train: 0.556, acc_valid: 0.520, auc_train: 1.000, auc_valid:0.850, time: 0.84 sec
# epoch 2, cross_loss: 0.637, acc_train: 0.990, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.841, time: 0.86 sec
# epoch 3, cross_loss: 0.435, acc_train: 0.838, acc_valid: 0.630, auc_train: 1.000, auc_valid:0.837, time: 0.86 sec
# epoch 4, cross_loss: 0.069, acc_train: 0.990, acc_valid: 0.710, auc_train: 1.000, auc_valid:0.830, time: 0.86 sec
# epoch 0, cross_loss: 0.126, acc_train: 0.970, acc_valid: 0.760, auc_train: 0.997, auc_valid:0.831, time: 0.86 sec
# epoch 1, cross_loss: 0.395, acc_train: 0.929, acc_valid: 0.720, auc_train: 0.998, auc_valid:0.842, time: 0.85 sec
# epoch 2, cross_loss: 0.239, acc_train: 0.980, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.857, time: 0.86 sec
# epoch 3, cross_loss: 0.186, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.864, time: 0.84 sec
# epoch 4, cross_loss: 0.062, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.864, time: 0.83 sec
# epoch 0, cross_loss: 0.435, acc_train: 0.909, acc_valid: 0.780, auc_train: 0.985, auc_valid:0.866, time: 0.82 sec
# epoch 1, cross_loss: 0.078, acc_train: 0.677, acc_valid: 0.570, auc_train: 0.995, auc_valid:0.879, time: 0.83 sec
# epoch 2, cross_loss: 0.139, acc_train: 0.778, acc_valid: 0.620, auc_train: 0.996, auc_valid:0.875, time: 0.83 sec
# epoch 3, cross_loss: 0.284, acc_train: 0.980, acc_valid: 0.790, auc_train: 0.998, auc_valid:0.881, time: 0.82 sec
# epoch 4, cross_loss: 0.130, acc_train: 0.960, acc_valid: 0.800, auc_train: 0.999, auc_valid:0.887, time: 0.83 sec
# /Users/martinweiss/.pyenv/versions/2.7.13/lib/python2.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
# Predict a gene from a growing number of Nodes
lr_results = pd.DataFrame([])
mlp_results = pd.DataFrame([])
cgn_results = pd.DataFrame([])
gene = "RPL5"
num_samples = 100
max_genes = 100
reload(data)
reload(models)
tcgatissue = data.gene_datasets.TCGATissue(data_dir='./genomics/TCGA/', data_file='TCGA_tissue_ppi.hdf5')
cgn_df = infer_gene(cgn, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=False)
lr_df = infer_gene(lr, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=True)
mlp_df = infer_gene(mlp, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=True)

for num_genes in range(10, max_genes, 10):
    neighbors = sample_neighbors(g, "RPL5", num_genes)
    tcgatissue.df = tcgatissue.df.loc[:, neighbors]
    lr_row = infer_gene(lr, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=True)
    lr_results = lr_results.append(lr_row).reset_index(drop=True)
    lr_results.loc[lr_results.index[-1], 'num_genes'] = num_genes
    cgn_row = infer_gene(cgn, tcgatissue, "RPL5", train_size=100, test_size=100, trials=3, penalty=True)
    cgn_results = cgn_results.append(cgn_row).reset_index(drop=True)
    cgn_results.loc[lr_results.index[-1], 'num_genes'] = num_genes
    tcgatissue = data.gene_datasets.TCGATissue(data_dir='./genomics/TCGA/', data_file='TCGA_tissue_ppi.hdf5')
    print num_genes
    print cgn_results
    print lr_results
# Out:
# Converting one-hot labels to integers
# epoch 0, cross_loss: 0.949, acc_train: 0.778, acc_valid: 0.630, auc_train: 1.000, auc_valid:0.850, time: 0.86 sec
# epoch 1, cross_loss: 0.057, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.843, time: 0.77 sec
# epoch 2, cross_loss: 0.019, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.846, time: 0.80 sec
# epoch 3, cross_loss: 0.057, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.846, time: 0.80 sec
# epoch 4, cross_loss: 0.074, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.844, time: 0.79 sec
# epoch 0, cross_loss: 0.250, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.854, time: 0.80 sec
# epoch 1, cross_loss: 0.104, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.861, time: 0.82 sec
# epoch 2, cross_loss: 0.276, acc_train: 0.990, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.864, time: 0.80 sec
# epoch 3, cross_loss: 0.083, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.870, time: 0.80 sec
# epoch 4, cross_loss: 0.088, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.873, time: 0.80 sec
# epoch 0, cross_loss: 0.069, acc_train: 0.768, acc_valid: 0.610, auc_train: 0.998, auc_valid:0.880, time: 0.79 sec
# epoch 1, cross_loss: 0.127, acc_train: 0.919, acc_valid: 0.820, auc_train: 1.000, auc_valid:0.885, time: 0.79 sec
# epoch 2, cross_loss: 0.110, acc_train: 0.929, acc_valid: 0.720, auc_train: 1.000, auc_valid:0.885, time: 0.80 sec
# epoch 3, cross_loss: 0.368, acc_train: 0.990, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.887, time: 0.81 sec
# epoch 4, cross_loss: 0.064, acc_train: 0.980, acc_valid: 0.820, auc_train: 1.000, auc_valid:0.884, time: 0.79 sec
# epoch 0, cross_loss: 0.224, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.865, time: 0.81 sec
# epoch 1, cross_loss: 0.107, acc_train: 0.646, acc_valid: 0.540, auc_train: 1.000, auc_valid:0.851, time: 0.79 sec
# epoch 2, cross_loss: 0.522, acc_train: 0.949, acc_valid: 0.710, auc_train: 1.000, auc_valid:0.837, time: 0.81 sec
# epoch 3, cross_loss: 0.047, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.830, time: 0.79 sec
# epoch 4, cross_loss: 0.040, acc_train: 0.980, acc_valid: 0.690, auc_train: 1.000, auc_valid:0.828, time: 0.82 sec
# epoch 0, cross_loss: 0.381, acc_train: 0.990, acc_valid: 0.720, auc_train: 1.000, auc_valid:0.823, time: 0.82 sec
# epoch 1, cross_loss: 0.084, acc_train: 0.960, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.838, time: 0.80 sec
# epoch 2, cross_loss: 0.047, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.839, time: 0.81 sec
# epoch 3, cross_loss: 0.043, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.846, time: 0.83 sec
# epoch 4, cross_loss: 0.047, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.848, time: 0.82 sec
# epoch 0, cross_loss: 0.214, acc_train: 0.980, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.862, time: 0.82 sec
# epoch 1, cross_loss: 0.188, acc_train: 0.980, acc_valid: 0.810, auc_train: 1.000, auc_valid:0.872, time: 0.81 sec
# epoch 2, cross_loss: 0.196, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.877, time: 0.80 sec
# epoch 3, cross_loss: 0.048, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.881, time: 0.78 sec
# epoch 4, cross_loss: 0.071, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.881, time: 0.78 sec
# Converting one-hot labels to integers
# 10
#     auc gene_name   std  num_genes
# 0  0.85      RPL5  0.02       10.0
#     auc gene_name   std  num_genes
# 0  0.76      RPL5  0.02       10.0
# epoch 0, cross_loss: 0.529, acc_train: 0.828, acc_valid: 0.610, auc_train: 1.000, auc_valid:0.845, time: 0.81 sec
# epoch 1, cross_loss: 0.016, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.841, time: 0.80 sec
# epoch 2, cross_loss: 0.055, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.839, time: 0.79 sec
# epoch 3, cross_loss: 0.046, acc_train: 1.000, acc_valid: 0.710, auc_train: 1.000, auc_valid:0.840, time: 0.81 sec
# epoch 4, cross_loss: 0.033, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.837, time: 0.79 sec
# epoch 0, cross_loss: 0.059, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.844, time: 0.80 sec
# epoch 1, cross_loss: 0.048, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.852, time: 0.82 sec
# epoch 2, cross_loss: 0.050, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.855, time: 0.84 sec
# epoch 3, cross_loss: 0.023, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.860, time: 0.80 sec
# epoch 4, cross_loss: 0.037, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.864, time: 0.84 sec
# epoch 0, cross_loss: 0.112, acc_train: 0.949, acc_valid: 0.700, auc_train: 1.000, auc_valid:0.871, time: 0.88 sec
# epoch 1, cross_loss: 0.123, acc_train: 0.990, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.865, time: 0.84 sec
# epoch 2, cross_loss: 0.204, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.872, time: 0.86 sec
# epoch 3, cross_loss: 0.394, acc_train: 0.859, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.873, time: 0.88 sec
# epoch 4, cross_loss: 0.068, acc_train: 1.000, acc_valid: 0.820, auc_train: 1.000, auc_valid:0.876, time: 0.88 sec
# Converting one-hot labels to integers
# 20
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# epoch 0, cross_loss: 0.766, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.852, time: 0.91 sec
# epoch 1, cross_loss: 0.395, acc_train: 0.859, acc_valid: 0.670, auc_train: 1.000, auc_valid:0.846, time: 0.92 sec
# epoch 2, cross_loss: 0.025, acc_train: 1.000, acc_valid: 0.710, auc_train: 1.000, auc_valid:0.836, time: 0.87 sec
# epoch 3, cross_loss: 0.016, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.835, time: 0.88 sec
# epoch 4, cross_loss: 0.015, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.830, time: 0.90 sec
# epoch 0, cross_loss: 0.045, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.832, time: 0.90 sec
# epoch 1, cross_loss: 0.028, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.840, time: 0.90 sec
# epoch 2, cross_loss: 0.051, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.846, time: 0.89 sec
# epoch 3, cross_loss: 0.011, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.853, time: 0.92 sec
# epoch 4, cross_loss: 0.013, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.857, time: 0.93 sec
# epoch 0, cross_loss: 0.056, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.856, time: 0.91 sec
# epoch 1, cross_loss: 0.021, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.862, time: 0.93 sec
# epoch 2, cross_loss: 0.022, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.868, time: 0.93 sec
# epoch 3, cross_loss: 0.015, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.871, time: 0.95 sec
# epoch 4, cross_loss: 0.025, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.871, time: 0.94 sec
# Converting one-hot labels to integers
# 30
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# epoch 0, cross_loss: 0.045, acc_train: 0.758, acc_valid: 0.600, auc_train: 1.000, auc_valid:0.850, time: 1.01 sec
# epoch 1, cross_loss: 0.022, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.843, time: 0.96 sec
# epoch 2, cross_loss: 0.056, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.841, time: 0.95 sec
# epoch 3, cross_loss: 0.025, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.840, time: 0.98 sec
# epoch 4, cross_loss: 0.014, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.836, time: 1.00 sec
# epoch 0, cross_loss: 0.014, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.844, time: 1.01 sec
# epoch 1, cross_loss: 0.021, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.848, time: 1.02 sec
# epoch 2, cross_loss: 0.018, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.850, time: 1.02 sec
# epoch 3, cross_loss: 0.008, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.849, time: 1.00 sec
# epoch 4, cross_loss: 0.013, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.850, time: 1.00 sec
# epoch 0, cross_loss: 0.013, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.855, time: 0.98 sec
# epoch 1, cross_loss: 0.017, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.861, time: 0.98 sec
# epoch 2, cross_loss: 0.024, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.864, time: 1.00 sec
# epoch 3, cross_loss: 0.014, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.865, time: 1.00 sec
# epoch 4, cross_loss: 0.021, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.865, time: 1.11 sec
# Converting one-hot labels to integers
# 40
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
# 3  0.85      RPL5       40.0  0.01
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# 3  0.80      RPL5       40.0  0.02
# epoch 0, cross_loss: 0.007, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.859, time: 1.06 sec
# epoch 1, cross_loss: 0.011, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.858, time: 0.98 sec
# epoch 2, cross_loss: 0.007, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.852, time: 1.02 sec
# epoch 3, cross_loss: 0.034, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.845, time: 0.99 sec
# epoch 4, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.839, time: 0.96 sec
# epoch 0, cross_loss: 0.279, acc_train: 0.869, acc_valid: 0.570, auc_train: 1.000, auc_valid:0.848, time: 1.01 sec
# epoch 1, cross_loss: 0.164, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.847, time: 0.98 sec
# epoch 2, cross_loss: 0.140, acc_train: 0.980, acc_valid: 0.650, auc_train: 1.000, auc_valid:0.843, time: 1.00 sec
# epoch 3, cross_loss: 0.018, acc_train: 0.960, acc_valid: 0.620, auc_train: 1.000, auc_valid:0.842, time: 0.99 sec
# epoch 4, cross_loss: 0.041, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.846, time: 1.00 sec
# epoch 0, cross_loss: 0.040, acc_train: 0.990, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.861, time: 1.01 sec
# epoch 1, cross_loss: 0.020, acc_train: 1.000, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.867, time: 1.01 sec
# epoch 2, cross_loss: 0.041, acc_train: 1.000, acc_valid: 0.720, auc_train: 1.000, auc_valid:0.868, time: 1.02 sec
# epoch 3, cross_loss: 0.028, acc_train: 1.000, acc_valid: 0.820, auc_train: 1.000, auc_valid:0.867, time: 1.00 sec
# epoch 4, cross_loss: 0.024, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.867, time: 1.02 sec
# Converting one-hot labels to integers
# 50
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
# 3  0.85      RPL5       40.0  0.01
# 4  0.85      RPL5       50.0  0.01
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# 3  0.80      RPL5       40.0  0.02
# 4  0.80      RPL5       50.0  0.03
# epoch 0, cross_loss: 0.519, acc_train: 0.919, acc_valid: 0.650, auc_train: 1.000, auc_valid:0.856, time: 1.03 sec
# epoch 1, cross_loss: 0.023, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.851, time: 0.97 sec
# epoch 2, cross_loss: 0.003, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.844, time: 1.00 sec
# epoch 3, cross_loss: 0.016, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.840, time: 1.01 sec
# epoch 4, cross_loss: 0.010, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.839, time: 0.96 sec
# epoch 0, cross_loss: 0.020, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.828, time: 0.99 sec
# epoch 1, cross_loss: 0.015, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.829, time: 1.02 sec
# epoch 2, cross_loss: 0.010, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.831, time: 1.01 sec
# epoch 3, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.833, time: 1.03 sec
# epoch 4, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.834, time: 1.00 sec
# epoch 0, cross_loss: 0.015, acc_train: 1.000, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.841, time: 1.00 sec
# epoch 1, cross_loss: 0.009, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.853, time: 1.01 sec
# epoch 2, cross_loss: 0.015, acc_train: 1.000, acc_valid: 0.680, auc_train: 1.000, auc_valid:0.859, time: 1.03 sec
# epoch 3, cross_loss: 0.027, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.860, time: 1.03 sec
# epoch 4, cross_loss: 0.012, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.862, time: 1.00 sec
# Converting one-hot labels to integers
# 60
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
# 3  0.85      RPL5       40.0  0.01
# 4  0.85      RPL5       50.0  0.01
# 5  0.85      RPL5       60.0  0.01
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# 3  0.80      RPL5       40.0  0.02
# 4  0.80      RPL5       50.0  0.03
# 5  0.79      RPL5       60.0  0.04
# epoch 0, cross_loss: 0.127, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.834, time: 1.00 sec
# epoch 1, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.823, time: 1.06 sec
# epoch 2, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.720, auc_train: 1.000, auc_valid:0.818, time: 1.00 sec
# epoch 3, cross_loss: 0.003, acc_train: 1.000, acc_valid: 0.690, auc_train: 1.000, auc_valid:0.817, time: 0.98 sec
# epoch 4, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.700, auc_train: 1.000, auc_valid:0.815, time: 1.01 sec
# epoch 0, cross_loss: 0.005, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.840, time: 1.04 sec
# epoch 1, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.847, time: 1.02 sec
# epoch 2, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.848, time: 1.04 sec
# epoch 3, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.847, time: 1.02 sec
# epoch 4, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.848, time: 1.02 sec
# epoch 0, cross_loss: 0.007, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.846, time: 1.00 sec
# epoch 1, cross_loss: 0.013, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.856, time: 1.05 sec
# epoch 2, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.856, time: 1.01 sec
# epoch 3, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.861, time: 1.01 sec
# epoch 4, cross_loss: 0.007, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.862, time: 1.00 sec
# Converting one-hot labels to integers
# 70
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
# 3  0.85      RPL5       40.0  0.01
# 4  0.85      RPL5       50.0  0.01
# 5  0.85      RPL5       60.0  0.01
# 6  0.84      RPL5       70.0  0.02
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# 3  0.80      RPL5       40.0  0.02
# 4  0.80      RPL5       50.0  0.03
# 5  0.79      RPL5       60.0  0.04
# 6  0.80      RPL5       70.0  0.03
# epoch 0, cross_loss: 0.014, acc_train: 0.970, acc_valid: 0.660, auc_train: 1.000, auc_valid:0.840, time: 1.06 sec
# epoch 1, cross_loss: 0.154, acc_train: 1.000, acc_valid: 0.690, auc_train: 1.000, auc_valid:0.835, time: 1.00 sec
# epoch 2, cross_loss: 0.114, acc_train: 1.000, acc_valid: 0.650, auc_train: 1.000, auc_valid:0.837, time: 1.00 sec
# epoch 3, cross_loss: 0.011, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.833, time: 1.02 sec
# epoch 4, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.690, auc_train: 1.000, auc_valid:0.832, time: 1.02 sec
# epoch 0, cross_loss: 0.012, acc_train: 1.000, acc_valid: 0.720, auc_train: 1.000, auc_valid:0.830, time: 1.02 sec
# epoch 1, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.750, auc_train: 1.000, auc_valid:0.831, time: 1.03 sec
# epoch 2, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.834, time: 1.01 sec
# epoch 3, cross_loss: 0.009, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.840, time: 1.01 sec
# epoch 4, cross_loss: 0.003, acc_train: 1.000, acc_valid: 0.760, auc_train: 1.000, auc_valid:0.839, time: 1.01 sec
# epoch 0, cross_loss: 0.008, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.838, time: 1.00 sec
# epoch 1, cross_loss: 0.005, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.842, time: 0.99 sec
# epoch 2, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.848, time: 1.01 sec
# epoch 3, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.849, time: 0.97 sec
# epoch 4, cross_loss: 0.004, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.850, time: 1.02 sec
# Converting one-hot labels to integers
# 80
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
# 3  0.85      RPL5       40.0  0.01
# 4  0.85      RPL5       50.0  0.01
# 5  0.85      RPL5       60.0  0.01
# 6  0.84      RPL5       70.0  0.02
# 7  0.84      RPL5       80.0  0.01
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# 3  0.80      RPL5       40.0  0.02
# 4  0.80      RPL5       50.0  0.03
# 5  0.79      RPL5       60.0  0.04
# 6  0.80      RPL5       70.0  0.03
# 7  0.80      RPL5       80.0  0.02
# epoch 0, cross_loss: 0.012, acc_train: 1.000, acc_valid: 0.670, auc_train: 1.000, auc_valid:0.830, time: 1.07 sec
# epoch 1, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.710, auc_train: 1.000, auc_valid:0.825, time: 1.02 sec
# epoch 2, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.825, time: 1.01 sec
# epoch 3, cross_loss: 0.000, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.828, time: 0.99 sec
# epoch 4, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.680, auc_train: 1.000, auc_valid:0.825, time: 1.02 sec
# epoch 0, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.740, auc_train: 1.000, auc_valid:0.829, time: 0.99 sec
# epoch 1, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.730, auc_train: 1.000, auc_valid:0.833, time: 0.99 sec
# epoch 2, cross_loss: 0.005, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.839, time: 1.00 sec
# epoch 3, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.720, auc_train: 1.000, auc_valid:0.842, time: 1.01 sec
# epoch 4, cross_loss: 0.003, acc_train: 1.000, acc_valid: 0.790, auc_train: 1.000, auc_valid:0.843, time: 1.01 sec
# epoch 0, cross_loss: 0.003, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.847, time: 1.01 sec
# epoch 1, cross_loss: 0.002, acc_train: 1.000, acc_valid: 0.770, auc_train: 1.000, auc_valid:0.849, time: 0.99 sec
# epoch 2, cross_loss: 0.008, acc_train: 1.000, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.852, time: 1.02 sec
# epoch 3, cross_loss: 0.003, acc_train: 1.000, acc_valid: 0.780, auc_train: 1.000, auc_valid:0.856, time: 1.01 sec
# epoch 4, cross_loss: 0.001, acc_train: 1.000, acc_valid: 0.800, auc_train: 1.000, auc_valid:0.861, time: 1.00 sec
# Converting one-hot labels to integers
# 90
#     auc gene_name  num_genes   std
# 0  0.85      RPL5       10.0  0.02
# 1  0.86      RPL5       20.0  0.02
# 2  0.85      RPL5       30.0  0.02
# 3  0.85      RPL5       40.0  0.01
# 4  0.85      RPL5       50.0  0.01
# 5  0.85      RPL5       60.0  0.01
# 6  0.84      RPL5       70.0  0.02
# 7  0.84      RPL5       80.0  0.01
# 8  0.84      RPL5       90.0  0.01
#     auc gene_name  num_genes   std
# 0  0.76      RPL5       10.0  0.02
# 1  0.75      RPL5       20.0  0.04
# 2  0.80      RPL5       30.0  0.04
# 3  0.80      RPL5       40.0  0.02
# 4  0.80      RPL5       50.0  0.03
# 5  0.79      RPL5       60.0  0.04
# 6  0.80      RPL5       70.0  0.03
# 7  0.80      RPL5       80.0  0.02
# 8  0.82      RPL5       90.0  0.03

# %%
# results of adding Nodes
plt.figure()

#full_results.loc[full_results['samples'] == 100]

line1 = plt.errorbar(lr_results.index, lr_results['auc'], xerr=0, yerr=lr_results['std'])
line2 = plt.errorbar(cgn_results.index, cgn_results['auc'], xerr=0, yerr=cgn_results['std'])

width = 0.2
plt.xticks(list(lr_results.iloc[::5, :].index), lr_results.iloc[::5, :]['num_genes'], rotation=70)
plt.title("Gene Inference with varying numbers of nodes")
plt.ylabel("AUC")
plt.xlabel("number of nodes")
plt.legend((line1[0], line2[0]), ('LR', "CGN"), bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., fontsize=10)

# %%
# Predict a gene from a growing number of Nodes
lr_results = pd.DataFrame([])
mlp_results = pd.DataFrame([])
cgn_results = pd.DataFrame([])
gene = "RPL5"
max_samples = 200
reload(data)
reload(models)
tcgatissue = data.gene_datasets.TCGATissue(data_dir='./genomics/TCGA/', data_file='TCGA_tissue_ppi.hdf5')

for num_samples in range(10, max_samples, 20):
    lr_row = infer_gene(lr, tcgatissue, "RPL5", train_size=num_samples, test_size=200, trials=3, penalty=True)
    lr_results = lr_results.append(lr_row).reset_index(drop=True)
    lr_results.loc[lr_results.index[-1], 'num_samples'] = num_samples
    cgn_row = infer_gene(cgn, tcgatissue, "RPL5", train_size=num_samples, test_size=200, trials=3, penalty=True)
    cgn_results = cgn_results.append(cgn_row).reset_index(drop=True)
    cgn_results.loc[lr_results.index[-1], 'num_samples'] = num_samples
    print num_genes
    print cgn_results
    print lr_results
# Out:
# Converting one-hot labels to integers
# epoch 0, cross_loss: 1.681, acc_train: 0.400, acc_valid: 0.465, auc_train: 1.000, auc_valid:0.575, time: 0.26 sec
# epoch 1, cross_loss: 3.655, acc_train: 0.400, acc_valid: 0.465, auc_train: 1.000, auc_valid:0.573, time: 0.08 sec
# epoch 2, cross_loss: 1.843, acc_train: 1.000, acc_valid: 0.555, auc_train: 1.000, auc_valid:0.569, time: 0.09 sec
# epoch 3, cross_loss: 0.230, acc_train: 0.600, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.567, time: 0.08 sec
# epoch 4, cross_loss: 0.752, acc_train: 0.600, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.566, time: 0.08 sec
# epoch 5, cross_loss: 1.091, acc_train: 0.600, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.566, time: 0.08 sec
# epoch 6, cross_loss: 0.989, acc_train: 0.600, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.567, time: 0.09 sec
# epoch 7, cross_loss: 0.768, acc_train: 0.600, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.567, time: 0.09 sec
# epoch 8, cross_loss: 0.509, acc_train: 0.800, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.567, time: 0.08 sec
# epoch 0, cross_loss: 0.964, acc_train: 0.500, acc_valid: 0.455, auc_train: 0.440, auc_valid:0.476, time: 0.08 sec
# epoch 1, cross_loss: 0.776, acc_train: 0.400, acc_valid: 0.535, auc_train: 0.440, auc_valid:0.482, time: 0.08 sec
# epoch 2, cross_loss: 0.765, acc_train: 0.500, acc_valid: 0.500, auc_train: 0.520, auc_valid:0.488, time: 0.08 sec
# epoch 3, cross_loss: 0.834, acc_train: 0.500, acc_valid: 0.500, auc_train: 0.640, auc_valid:0.496, time: 0.09 sec
# epoch 4, cross_loss: 0.900, acc_train: 0.500, acc_valid: 0.500, auc_train: 0.720, auc_valid:0.504, time: 0.09 sec
# epoch 5, cross_loss: 0.878, acc_train: 0.500, acc_valid: 0.500, auc_train: 0.760, auc_valid:0.511, time: 0.08 sec
# epoch 6, cross_loss: 0.822, acc_train: 0.500, acc_valid: 0.500, auc_train: 0.800, auc_valid:0.518, time: 0.09 sec
# epoch 7, cross_loss: 0.765, acc_train: 0.500, acc_valid: 0.500, auc_train: 0.840, auc_valid:0.527, time: 0.09 sec
# epoch 8, cross_loss: 0.692, acc_train: 0.500, acc_valid: 0.505, auc_train: 0.880, auc_valid:0.534, time: 0.09 sec
# epoch 0, cross_loss: 0.616, acc_train: 0.700, acc_valid: 0.505, auc_train: 0.571, auc_valid:0.514, time: 0.08 sec
# epoch 1, cross_loss: 0.631, acc_train: 0.700, acc_valid: 0.505, auc_train: 0.571, auc_valid:0.518, time: 0.08 sec
# 90
#     auc gene_name   std  num_samples
# 0  0.55      RPL5  0.02         10.0
#     auc gene_name   std  num_samples
# 0  0.51      RPL5  0.03         10.0
# epoch 0, cross_loss: 0.850, acc_train: 0.667, acc_valid: 0.510, auc_train: 0.990, auc_valid:0.565, time: 0.49 sec
# epoch 1, cross_loss: 0.563, acc_train: 0.767, acc_valid: 0.535, auc_train: 1.000, auc_valid:0.553, time: 0.25 sec
# epoch 2, cross_loss: 0.376, acc_train: 1.000, acc_valid: 0.515, auc_train: 1.000, auc_valid:0.534, time: 0.25 sec
# epoch 3, cross_loss: 0.312, acc_train: 0.767, acc_valid: 0.510, auc_train: 1.000, auc_valid:0.515, time: 0.24 sec
# epoch 4, cross_loss: 0.299, acc_train: 1.000, acc_valid: 0.515, auc_train: 1.000, auc_valid:0.497, time: 0.25 sec
# epoch 5, cross_loss: 0.263, acc_train: 1.000, acc_valid: 0.470, auc_train: 1.000, auc_valid:0.491, time: 0.25 sec
# epoch 6, cross_loss: 0.095, acc_train: 1.000, acc_valid: 0.505, auc_train: 1.000, auc_valid:0.489, time: 0.24 sec
# epoch 7, cross_loss: 0.113, acc_train: 1.000, acc_valid: 0.520, auc_train: 1.000, auc_valid:0.489, time: 0.25 sec
# epoch 8, cross_loss: 0.032, acc_train: 1.000, acc_valid: 0.465, auc_train: 1.000, auc_valid:0.492, time: 0.25 sec
# epoch 0, cross_loss: 2.032, acc_train: 0.667, acc_valid: 0.500, auc_train: 0.584, auc_valid:0.554, time: 0.24 sec
# epoch 1, cross_loss: 0.651, acc_train: 0.533, acc_valid: 0.560, auc_train: 0.833, auc_valid:0.563, time: 0.24 sec
