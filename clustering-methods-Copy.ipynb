# %%
import os
import time
import pickle
import numpy as np
import matplotlib, matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import torch
import itertools
from torch.autograd import Variable
import sklearn, sklearn.model_selection, sklearn.metrics
import numpy as np

from models.model_wrapper import MLP, GCN, SLR
from data import datasets
from data.gene_graphs import GeneManiaGraph
from data.utils import record_result

# %%
dataset = datasets.TCGADataset()
dataset.df = dataset.df - dataset.df.mean(axis=0)
# Out:
# Torrent name: TCGA_tissue_ppi.hdf5, Size: 1748.32MB
# Checking for pieces on disk: |██████████████████████████████████████████████████| 100.0%
# Found 1668 finished pieces out of 1668 total pieces.
# Found dataset at /Users/martinweiss/.academictorrents-datastore/TCGA_tissue_ppi.hdf5
# Converting one-hot labels to integers

# %%
# Setup the results dictionary
filename = "experiments/results/fig-5.pkl"
try:
    results = pickle.load(open(filename, "rb"), encoding='latin1')
    print("Loaded Checkpointed Results")
except Exception as e:
    results = pd.DataFrame(columns=['auc', 'gene', 'model', 'num_genes', 'seed', 'train_size', 'time_elapsed'])
    print("Created a New Results Dictionary")
# Out:
# Loaded Checkpointed Results

# %%
gene_graph = GeneManiaGraph()
# Out:
# Torrent name: genemania.pkl, Size: 9.61MB
# Checking for pieces on disk: |██████████████████████████████████████████████████| 100.0%
# Found 294 finished pieces out of 294 total pieces.
# Found dataset at /Users/martinweiss/.academictorrents-datastore/genemania.pkl

# %%
search_num_genes=[50, 100, 200, 300, 500, 1000]
test_size=1000
search_train_size=[50]
cuda=False
trials=5
search_genes = ["RPL4", "IL5", "CEBPD", ]#"RPL5", "RPS10", "RPS3",  "PABPC3", "PSMB10", "S100A8", "S100A9", "TOP1", "C15orf40", "RNF138", "DLGAP2", "EVI2B", "ZFP82", "MYBL2", "PSMB1", "CISD1", "HLA-B", "SAA2", "IFIT1", "RPS3A", "TP53", "TNF", "EGFR"]
model_list = [           
              GCN(name="GCN_lay20_chan32_emb32_dropout_pool_hierarchy", cuda=cuda, num_layer=4, channels=32, embedding=32, prepool_extralayers=5, pooling="hierarchy"),
              GCN(name="GCN_lay20_chan32_emb32_dropout_pool_random", cuda=cuda, num_layer=4, channels=32, embedding=32, prepool_extralayers=5, pooling="random"),
#               GCN(name="GCN_lay3_chan64_emb32_pool_hierarchy", cuda=cuda, dropout=True, num_layer=3, channels=64, embedding=32, pooling="hierarchy"),
#               GCN(name="GCN_lay3_chan64_emb32_pool_random", cuda=cuda, dropout=True, num_layer=3, channels=64, embedding=32, pooling="random"),
              MLP(name="MLP_lay2_chan512_dropout", cuda=cuda, dropout=True, num_layer=2, channels=512),
              MLP(name="MLP_lay2_chan512", cuda=cuda, dropout=False, num_layer=2, channels=512),
              SLR(name="SLR_lambda1_l11", cuda=cuda)
             ]

# %%
# Create the set of all experiment ids and see which are left to do
model_names = [model.name for model in model_list]
columns = ["gene", "model", "num_genes", "train_size", "seed"]
all_exp_ids = [x for x in itertools.product(search_genes, model_names, search_num_genes, search_train_size, range(trials))]
all_exp_ids = pd.DataFrame(all_exp_ids, columns=columns)
all_exp_ids.index = ["-".join(map(str, tup[1:])) for tup in all_exp_ids.itertuples(name=None)]
results_exp_ids = results[columns].copy()
results_exp_ids.index = ["-".join(map(str, tup[1:])) for tup in results_exp_ids.itertuples(name=None)]
intersection_ids = all_exp_ids.index.intersection(results_exp_ids.index)
todo = all_exp_ids.drop(intersection_ids).to_dict(orient="records")
print("todo: " + str(len(todo)))
print("done: " + str(len(results)))
# Out:
# todo: 208
# done: 1130

# %%
def get_every_n(a, n=2):
    for i in range(a.shape[0] // 2):
        yield a[2*i:2*(i+1)]

# %%
for row in todo:
    print(row)
    start_time = time.time()
    gene = row["gene"]
    model_name = row["model"]
    seed = row["seed"]
    num_genes = row["num_genes"]
    train_size = row["train_size"]

    model = [x for x in model_list if x.name == model_name][0]

    experiment = {
        "gene": gene,
        "model": model.name,
        "num_genes": num_genes,
        "train_size": train_size,
        "seed": seed,
    }

    dataset.labels = dataset.df[gene].where(dataset.df[gene] > 0).notnull().astype("int")
    X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(dataset.df, dataset.labels, stratify=dataset.labels, train_size=train_size, test_size=test_size, random_state=seed)

    neighbors = gene_graph.bfs_sample_neighbors(gene, num_genes)

    X_train = X_train[list(neighbors.nodes)].copy()
    X_test = X_test[list(neighbors.nodes)].copy()
    X_train[gene] = 1
    X_test[gene] = 1
    adj = np.asarray(nx.to_numpy_matrix(neighbors))
    model.fit(X_train, y_train, adj=adj)
    
    x_test = Variable(torch.FloatTensor(np.expand_dims(X_test.values, axis=2)), requires_grad=False).float()
    if cuda:
        x_test = x_test.cuda()
    
    y_hat = []
    for chunk in get_every_n(x_test, 10):
        y_hat.extend(model.predict(chunk)[:,1].data.cpu().numpy().tolist())
    auc = sklearn.metrics.roc_auc_score(y_test, np.asarray(y_hat).flatten())

    del model
    experiment["auc"] = auc
    experiment["time_elapsed"] = str(time.time() - start_time)
    experiment["cuda"] = cuda
    results = record_result(results, experiment, filename)
    print("time elapsed for genes: " +str(num_genes) + " : " + str(time.time() - start_time))
# Out:
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 50 : 4.576353073120117
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 50 : 6.7867751121521
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 50 : 3.8881969451904297
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# 0.0174560546875
# 0.03151512145996094
# 0.030670166015625
# 0.03873014450073242
# time elapsed for genes: 100 : 4.48417592048645
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.671916961669922
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.3390820026397705
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 100 : 7.0920610427856445
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 100 : 5.547691822052002
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# 0.02707505226135254
# 0.48827290534973145
# 0.12094616889953613
# 0.12681198120117188
# time elapsed for genes: 200 : 6.008530139923096
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.477383852005005
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.7742919921875
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.750047922134399
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 200 : 6.197393178939819
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# 0.050866127014160156
# 0.2204899787902832
# 0.28992795944213867
# 0.34696316719055176
# time elapsed for genes: 300 : 7.6271138191223145
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 300 : 7.369149923324585
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 300 : 7.7829999923706055
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 300 : 8.24180793762207
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 300 : 7.488921165466309
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# 0.1329209804534912
# 0.7598071098327637
# 1.1248390674591064
# 1.1539130210876465
# time elapsed for genes: 500 : 18.130926847457886
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 500 : 10.439069032669067
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 500 : 11.102396965026855
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 500 : 13.748062133789062
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 500 : 10.557440996170044
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# 0.848106861114502
# 4.782374858856201
# 6.349962949752808
# 7.2637529373168945
# time elapsed for genes: 1000 : 45.783668994903564
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 26.362700939178467
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 27.454057931900024
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 39.44582009315491
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 25.89196491241455
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 50 : 4.16679310798645
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 50 : 3.803611993789673
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 50 : 3.8110249042510986
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 50 : 4.214201211929321
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 50 : 3.9752111434936523
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.1359357833862305
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.101571083068848
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.203732967376709
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.447298049926758
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 100 : 4.168760061264038
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.2586891651153564
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.7883570194244385
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.465072870254517
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.195527791976929
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 200 : 5.10604190826416
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 300 : 8.812943935394287
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 300 : 6.700459003448486
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 300 : 6.640594959259033
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 300 : 6.744251012802124
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 300 : 6.650364875793457
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 500 : 19.512290954589844
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 500 : 11.388816118240356
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 500 : 13.711400985717773
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 500 : 17.924697160720825
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 500 : 10.163872003555298
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 25.822662115097046
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 26.855994939804077
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 25.952797889709473
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 38.2488751411438
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 27.45436191558838
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 50, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.871157169342041
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 50, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.6575491428375244
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.6400191783905029
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.49050307273864746
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.6023540496826172
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5492429733276367
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5864291191101074
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.6804540157318115
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5574169158935547
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.6956119537353516
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.7195699214935303
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.7054181098937988
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.6175119876861572
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.6263201236724854
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.6881129741668701
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.7545280456542969
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.7073509693145752
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.6469919681549072
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.6741218566894531
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.7389340400695801
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.899183988571167
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 500 : 1.174881935119629
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.8166899681091309
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7556140422821045
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7534399032592773
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.8009889125823975
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.5870239734649658
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.5131311416625977
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.108820915222168
# {'model': 'MLP_lay2_chan512_dropout', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.4997859001159668
# {'model': 'MLP_lay2_chan512', 'num_genes': 50, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.5619468688964844
# {'model': 'MLP_lay2_chan512', 'num_genes': 50, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.45560789108276367
# {'model': 'MLP_lay2_chan512', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.6004641056060791
# {'model': 'MLP_lay2_chan512', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.47899293899536133
# {'model': 'MLP_lay2_chan512', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.46717381477355957
# {'model': 'MLP_lay2_chan512', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.538517951965332
# {'model': 'MLP_lay2_chan512', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5922999382019043
# {'model': 'MLP_lay2_chan512', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5053601264953613
# {'model': 'MLP_lay2_chan512', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5258960723876953
# {'model': 'MLP_lay2_chan512', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.5361130237579346
# {'model': 'MLP_lay2_chan512', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.7156620025634766
# {'model': 'MLP_lay2_chan512', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.5651500225067139
# {'model': 'MLP_lay2_chan512', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.5641570091247559
# {'model': 'MLP_lay2_chan512', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.5671589374542236
# {'model': 'MLP_lay2_chan512', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.6229279041290283
# {'model': 'MLP_lay2_chan512', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.6155190467834473
# {'model': 'MLP_lay2_chan512', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.608253002166748
# {'model': 'MLP_lay2_chan512', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.7412848472595215
# {'model': 'MLP_lay2_chan512', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.6136188507080078
# {'model': 'MLP_lay2_chan512', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.6068630218505859
# {'model': 'MLP_lay2_chan512', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7136530876159668
# {'model': 'MLP_lay2_chan512', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7882931232452393
# {'model': 'MLP_lay2_chan512', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7378840446472168
# {'model': 'MLP_lay2_chan512', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7422268390655518
# {'model': 'MLP_lay2_chan512', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.7701799869537354
# {'model': 'MLP_lay2_chan512', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.0547659397125244
# {'model': 'MLP_lay2_chan512', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.1431071758270264
# {'model': 'MLP_lay2_chan512', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.433885097503662
# {'model': 'MLP_lay2_chan512', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.0560801029205322
# {'model': 'MLP_lay2_chan512', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 1.2059378623962402
# {'model': 'SLR_lambda1_l11', 'num_genes': 50, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.18363499641418457
# {'model': 'SLR_lambda1_l11', 'num_genes': 50, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.18745803833007812
# {'model': 'SLR_lambda1_l11', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.15305209159851074
# {'model': 'SLR_lambda1_l11', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.16513514518737793
# {'model': 'SLR_lambda1_l11', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 50 : 0.13805699348449707
# {'model': 'SLR_lambda1_l11', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.16985797882080078
# {'model': 'SLR_lambda1_l11', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.23300790786743164
# {'model': 'SLR_lambda1_l11', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.15996503829956055
# {'model': 'SLR_lambda1_l11', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.17113280296325684
# {'model': 'SLR_lambda1_l11', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 100 : 0.1825568675994873
# {'model': 'SLR_lambda1_l11', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.19228887557983398
# {'model': 'SLR_lambda1_l11', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.1873769760131836
# {'model': 'SLR_lambda1_l11', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.18358111381530762
# {'model': 'SLR_lambda1_l11', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.18032598495483398
# {'model': 'SLR_lambda1_l11', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 200 : 0.1819770336151123
# {'model': 'SLR_lambda1_l11', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.20237302780151367
# {'model': 'SLR_lambda1_l11', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.23319697380065918
# {'model': 'SLR_lambda1_l11', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.24128103256225586
# {'model': 'SLR_lambda1_l11', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.22902894020080566
# {'model': 'SLR_lambda1_l11', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 300 : 0.21410489082336426
# {'model': 'SLR_lambda1_l11', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.2575850486755371
# {'model': 'SLR_lambda1_l11', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.26874709129333496
# {'model': 'SLR_lambda1_l11', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.25721096992492676
# {'model': 'SLR_lambda1_l11', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.2739908695220947
# {'model': 'SLR_lambda1_l11', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 500 : 0.2621769905090332
# {'model': 'SLR_lambda1_l11', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 0.4659759998321533
# {'model': 'SLR_lambda1_l11', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 0.46390604972839355
# {'model': 'SLR_lambda1_l11', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 0.4644801616668701
# {'model': 'SLR_lambda1_l11', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 0.8464109897613525
# {'model': 'SLR_lambda1_l11', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'IL5'}
# time elapsed for genes: 1000 : 0.4808831214904785
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# 0.018898963928222656
# 0.017841100692749023
# 0.018563032150268555
# 0.01978588104248047
# time elapsed for genes: 50 : 6.262161016464233
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 4.853603839874268
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 3.937082052230835
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 4.424551010131836
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 5.695833921432495
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# 0.02294611930847168
# 0.037960052490234375
# 0.040483951568603516
# 0.041825056076049805
# time elapsed for genes: 100 : 6.22223687171936
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.3082780838012695
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 5.577088117599487
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 5.9033730030059814
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.282495975494385
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# 0.042222023010253906
# 0.10661697387695312
# 0.12778401374816895
# 0.13341307640075684
# time elapsed for genes: 200 : 7.897990942001343
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 11.081873893737793
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 6.29007887840271
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 6.783293962478638
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 5.8692121505737305
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# 0.08614897727966309
# 0.2722890377044678
# 0.3216700553894043
# 0.3336770534515381
# time elapsed for genes: 300 : 12.278805017471313
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 11.79654598236084
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 12.815421104431152
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 8.664176940917969
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 8.801822900772095
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# 0.2571678161621094
# 0.7966971397399902
# 1.2182950973510742
# 1.2590851783752441
# time elapsed for genes: 500 : 19.978173971176147
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 26.22240900993347
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 19.40525794029236
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 23.483914852142334
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 21.187511920928955
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# 0.8960058689117432
# 4.332955837249756
# 6.515311002731323
# 6.8500330448150635
# time elapsed for genes: 1000 : 56.73727512359619
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 50.649600982666016
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 41.91382598876953
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 30.69930601119995
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_hierarchy', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 29.742969036102295
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 3.98006010055542
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 4.192265033721924
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 5.817969799041748
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 3.8854432106018066
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 50, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 50 : 5.816822052001953
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.3396079540252686
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.438737869262695
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.314340114593506
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.643533945083618
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 100, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 100 : 4.311517000198364
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 8.35675311088562
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 9.474178791046143
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 7.340726137161255
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 10.530838966369629
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 200, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 200 : 8.998694896697998
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 13.729959964752197
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 12.85520601272583
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 12.111074209213257
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 8.558600187301636
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 300, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 300 : 8.631987810134888
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 19.544111013412476
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 15.014609813690186
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 20.00080704689026
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 16.038700103759766
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 500, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 500 : 19.457898139953613
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 0, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 39.84224009513855
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 1, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 41.1259400844574
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 2, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 44.131712198257446
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 3, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 35.70590400695801
# {'model': 'GCN_lay20_chan32_emb32_dropout_pool_random', 'num_genes': 1000, 'train_size': 50, 'seed': 4, 'gene': 'CEBPD'}
# time elapsed for genes: 1000 : 59.98161602020264

# %%
set(results.model)
# Out:
# {'GCN_lay20_chan32_emb32_dropout_more_pool',
#  'GCN_lay20_chan32_emb32_dropout_pool',
#  'GCN_lay20_chan32_emb32_dropout_pool_hierarchy',
#  'GCN_lay20_chan32_emb32_dropout_pool_random',
#  'GCN_lay3_chan64_emb32_dropout',
#  'MLP_lay2_chan512',
#  'MLP_lay2_chan512_dropout',
#  'SLR_lambda1_l11'}

# %%
for plot_gene in search_genes:

    # %matplotlib inline
    plt.rcParams['figure.figsize'] = (7.5, 3.6)
    plot_train_size = 50

    subset = results[(results.train_size==plot_train_size) & 
                      (results.gene==plot_gene) & 
                      (results.num_genes!=400) &      
                      (results.model != "GCN_lay3_chan64_emb32") & 
                      (results.model != "GCN_lay20_chan32_emb32_dropout_pool") & 
                      (results.model != "GCN_lay20_chan32_emb32_dropout_more_pool") & 
                      (results.num_genes> 0)]


    q = subset.groupby(['model','num_genes'])['auc']

    todo = list(subset["model"].unique())
    linestyles = ['-', '-', '--', '-.', ':']
    for ls, model in enumerate(sorted(todo)):
        index = list(q.mean()[model].index)
        mean = q.mean()[model]
        stderr = q.std()[model]/np.sqrt(q.count()[model])
        displayname = model.replace("CGN","GCN")
        displayname = displayname.replace("SLR", "SNLR")
        plt.errorbar(index, mean, label=displayname, xerr=0, yerr=stderr, ls=linestyles[ls])

    plt.title("Gene Inference " + plot_gene + " (train_size:" + str(plot_train_size) +")")
    plt.ylabel("AUC")
    plt.xlabel("Number of genes")
    plt.xscale("log")
    plt.xticks(sorted(subset["num_genes"].unique()))
    formatter = matplotlib.ticker.ScalarFormatter()
    plt.gca().xaxis.set_major_formatter(formatter)

    plt.legend();
    fd = len(list(gene_graph.nx_graph.neighbors(plot_gene)))
    print(fd)
    if fd > 50:
        plt.axvline(fd, ymin=0.4, ymax=1.0, c="black")
        c = plt.ylim()
        plt.text(fd*1.05,c[1]-((c[1]-c[0])*0.2),'First Degree',rotation=90)


    plt.savefig("experiments/results/sgi-" + plot_gene + "-" + "train" + str(plot_train_size) + ".png", bbox_inches='tight')
    plt.show()
# Out:
# 206
# 3
# 34
