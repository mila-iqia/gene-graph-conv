# %%
# This file generates the data for Figure #4 from the paper https://arxiv.org/pdf/1806.06975.pdf

import os 
import sys
import pickle
import argparse
import networkx as nx
import operator

import pandas as pd
import numpy as np

import itertools
import sklearn
import torch
import datetime
import matplotlib, matplotlib.pyplot as plt
from collections import defaultdict

from torch.autograd import Variable
from models.models import MLP
from data import datasets
from data.gene_graphs import GeneManiaGraph, RegNetGraph
from data.utils import record_result

# %%
graphs = {"regnet": RegNetGraph(), "genemania": GeneManiaGraph()}
# Out:
# Torrent name: regnet.pkl, Size: 8.81MB
# Checking for pieces on disk: |██████████████████████████████████████████████████| 100.0%
# Found 0 finished pieces out of 269 total pieces.
# Downloading to /home/martin/.academictorrents-datastore/regnet.pkl
# BT:0, Web:0 |--------------------------------------------------| 0.0% (0.00kB/s)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-15dddeb9df10> in <module>
# ----> 1 graphs = {"regnet": RegNetGraph(), "genemania": GeneManiaGraph()}
#
# /media/martin/the_milano/code/academic/gene-graph-conv/data/gene_graphs.py in __init__(self, at_hash, datastore)
#      49         self.at_hash = at_hash
#      50         self.datastore = datastore
# ---> 51         super(RegNetGraph, self).__init__()
#      52
#      53     def load_data(self):
#
# /media/martin/the_milano/code/academic/gene-graph-conv/data/gene_graphs.py in __init__(self)
#      13     """
#      14     def __init__(self):
# ---> 15         self.load_data()
#      16
#      17     def load_data(self):
#
# /media/martin/the_milano/code/academic/gene-graph-conv/data/gene_graphs.py in load_data(self)
#      52
#      53     def load_data(self):
# ---> 54         self.nx_graph = nx.OrderedGraph(nx.readwrite.gpickle.read_gpickle(at.get(self.at_hash, datastore=self.datastore)))
#      55
#      56
#
# /media/martin/the_milano/anaconda3/lib/python3.7/site-packages/academictorrents/academictorrents.py in get(at_hash, datastore, urls, showlogs)
#      33     else:
#      34         print("Downloading to " + path)
# ---> 35         Client(torrent, downloaded_amount, piece_manager).start()
#      36
#      37     write_timestamp(at_hash)
#
# /media/martin/the_milano/anaconda3/lib/python3.7/site-packages/academictorrents/Client.py in start(self)
#      46             progress_bar.print_progress(cur_downloaded, self.torrent.total_length, "BT:{}, Web:{}".format(len(self.peer_manager.peers), len(self.peer_manager.http_peers)), "({0:.2f}kB/s)".format(rate)) # + " Downloaded " + str(round(cur_downloaded/1000000., 2)) + "MB" )
#      47             self.tracker.set_downloaded(cur_downloaded)
# ---> 48             time.sleep(0.1)
#      49
#      50         cur_downloaded = self.piece_manager.check_finished_pieces()
#
# KeyboardInterrupt:

# %%
# Setup the results dictionary
filename = "experiments/results/graph-gen.pkl"
try:
    results = pickle.load(open(filename, "rb"), encoding='latin1')
    print("Loaded Checkpointed Results")
except Exception as e:
    print(e)
    results = pd.DataFrame(columns=['auc', 'gene', 'model', 'graph', 'is_first_degree', 'seed', 'train_size', 'optimize_graph_results'])
    print("Created a New Results Dictionary")
# Out:
# [Errno 2] No such file or directory: 'experiments/results/graph-gen.pkl'
# Created a New Results Dictionary

# %%
train_size = 50
test_size = 1000
trials = 3
cuda = False
models = {"BasicMLP": MLP(column_names=dataset.df.columns, dropout=False, cuda=cuda)}

# %%
# Create the set of all experiment ids and see which are left to do
columns = ["gene", "graph", "model", "seed", "is_first_degree", "train_size"]
all_exp_ids = [x for x in itertools.product(dataset.df.columns, graphs.keys(), models.keys(), range(trials), [True, False], [train_size])]
all_exp_ids = pd.DataFrame(all_exp_ids, columns=columns)
all_exp_ids.index = ["-".join(map(str, tup[1:])) for tup in all_exp_ids.itertuples(name=None)]
results_exp_ids = results[columns].copy()
results_exp_ids.index = ["-".join(map(str, tup[1:])) for tup in results_exp_ids.itertuples(name=None)]
intersection_ids = all_exp_ids.index.intersection(results_exp_ids.index)
todo = all_exp_ids.drop(intersection_ids).to_dict(orient="records")

print("todo: " + str(len(todo)))
print("done: " + str(len(results)))
# Out:
# todo: 195600
# done: 0

# %%
def optimize_graph(model, gene_graph, gene, X_train, X_test, y_train, y_test):
    neighbors = list(gene_graph.first_degree(gene)[0])
    neighbors = [n for n in neighbors if n in X_train.columns.values]
    res = {}
    for neighbor in neighbors:
        candidate_nodes = neighbors if gene == neighbor else set(neighbors) - set(neighbor)
        x_train = X_train.loc[:, candidate_nodes].copy()
        x_test = X_test.loc[:, candidate_nodes].copy()
        x_train[gene] = 1
        x_test[gene] = 1

        try:
            model.fit(x_train, y_train)
            x_test = Variable(torch.FloatTensor(np.expand_dims(x_test.values, axis=2)), requires_grad=False).float()
            if cuda:
                x_test = x_test.cuda()
            y_hat = model.predict(x_test)[:, 1].data.cpu().numpy()
            auc = sklearn.metrics.roc_auc_score(y_test, np.asarray(y_hat).flatten())
            res[neighbor] = auc
            model.best_model = None # cleanup

        except Exception as e:
            print(e)
    return res

# %%
optimize_graph_results = []

for row in todo:
    if len(results) % 10 == 0:
        print(len(results))
    gene = row["gene"]
    graph_name = row["graph"]
    model_name = row["model"]
    seed = row["seed"]
    is_first_degree = row["is_first_degree"]
    model = models[model_name]

    experiment = {
        "gene": gene,
        "model": model_name,
        "graph": graph_name,
        "is_first_degree": is_first_degree,
        "seed": seed,
        "train_size": train_size,
        "optimize_graph_results": None,
    }
    dataset.labels = dataset.df[gene].where(dataset.df[gene] > 0).notnull().astype("int")
    try:
        X_train, X_test, y_train, y_test = sklearn.model_selection.\
            train_test_split(dataset.df, dataset.labels, stratify=dataset.labels, 
                             train_size=train_size, test_size=test_size)
    except ValueError:
        results = record_result(results, experiment, filename)
        continue

    if is_first_degree:
        gene_graph = graphs[graph_name]
        experiment["optimize_graph_results"] = optimize_graph(model, gene_graph, gene, X_train, X_test, y_train, y_test)
    else:
        X_train = X_train.copy()
        X_test = X_test.copy()

        X_train[gene] = 1
        X_test[gene] = 1

        try:
            model.fit(X_train, y_train)

            x_test = Variable(torch.FloatTensor(np.expand_dims(X_test.values, axis=2)), requires_grad=False).float()
            if cuda:
                x_test = x_test.cuda()
            y_hat = model.predict(x_test)[:, 1].data.cpu().numpy()
            auc = sklearn.metrics.roc_auc_score(y_test, np.asarray(y_hat).flatten())
            model.best_model = None # cleanup
            experiment["auc"] = auc
        except Exception as e:
            print(e)
    results = record_result(results, experiment, filename)
# Out:
# 40
# 50
# 60
# 70
# 80
# 90
# 'NoneType' object has no attribute 'copy'
# 100
# 110
# 120
# 130
# 140
# 150
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 160
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 170
# 180
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 190
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 200
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 210
# 'NoneType' object has no attribute 'copy'
# 220
# 230
# 240
# 250
# 260
# 'NoneType' object has no attribute 'copy'
# 270
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 280
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 290
# 300
# 310
# 320
# 330
# 340
# 350
# 360
# 370
# 'NoneType' object has no attribute 'copy'
# 380
# 390
# 400
# 410
# 420
# 430
# 440
# 450
# 460
# 470
# 480
# 490
# 500
# 510
# 520
# 'NoneType' object has no attribute 'copy'
# 530
# 540
# 550
# 560
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 570
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# Only one class present in y_true. ROC AUC score is not defined in that case.
# 580
# 590
# 600
# 610
# 620
# 630
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-7be8411c08f8> in <module>
#      31     if is_first_degree:
#      32         gene_graph = graphs[graph_name]
# ---> 33         experiment["optimize_graph_results"] = optimize_graph(model, gene_graph, gene, X_train, X_test, y_train, y_test)
#      34     else:
#      35         X_train = X_train.copy()
#
# <ipython-input-15-d6c5f9101dd2> in optimize_graph(model, gene_graph, gene, X_train, X_test, y_train, y_test)
#      11
#      12         try:
# ---> 13             model.fit(x_train, y_train)
#      14             x_test = Variable(torch.FloatTensor(np.expand_dims(x_test.values, axis=2)), requires_grad=False).float()
#      15             if cuda:
#
# ~/code/academic/conv-graph/models/model_wrapper.py in fit(self, X, y, adj)
#      92                 optimizer.zero_grad()
#      93                 loss.backward()
# ---> 94                 optimizer.step()
#      95                 self.eval()
#      96
#
# ~/code/academic/conv-graph/venv/lib/python3.5/site-packages/torch/optim/adam.py in step(self, closure)
#      80                         state['max_exp_avg_sq'] = torch.zeros_like(p.data)
#      81
# ---> 82                 exp_avg, exp_avg_sq = state['exp_avg'], state['exp_avg_sq']
#      83                 if amsgrad:
#      84                     max_exp_avg_sq = state['max_exp_avg_sq']
#
# KeyboardInterrupt:

# %%
results
# Out:
#           auc     gene     model      graph is_first_degree seed train_size  \
# 0         NaN   UBE2Q1  BasicMLP  genemania            True    0         50
# 1    0.704233   UBE2Q1  BasicMLP  genemania           False    0         50
# 2         NaN   UBE2Q1  BasicMLP  genemania            True    1         50
# 3    0.644115   UBE2Q1  BasicMLP  genemania           False    1         50
# 4         NaN   UBE2Q1  BasicMLP  genemania            True    2         50
# 5    0.673705   UBE2Q1  BasicMLP  genemania           False    2         50
# 6         NaN   UBE2Q1  BasicMLP     regnet            True    0         50
# 7    0.692846   UBE2Q1  BasicMLP     regnet           False    0         50
# 8         NaN   UBE2Q1  BasicMLP     regnet            True    1         50
# 9    0.622473   UBE2Q1  BasicMLP     regnet           False    1         50
# 10        NaN   UBE2Q1  BasicMLP     regnet            True    2         50
# 11   0.640115   UBE2Q1  BasicMLP     regnet           False    2         50
# 12        NaN   UBE2Q1  BasicMLP  genemania            True    0         50
# 13   0.728144   UBE2Q1  BasicMLP  genemania           False    0         50
# 14        NaN   UBE2Q1  BasicMLP  genemania            True    1         50
# 15   0.711847   UBE2Q1  BasicMLP  genemania           False    1         50
# 16        NaN   UBE2Q1  BasicMLP  genemania            True    2         50
# 17   0.721294   UBE2Q1  BasicMLP  genemania           False    2         50
# 18        NaN   UBE2Q1  BasicMLP     regnet            True    0         50
# 19   0.681867   UBE2Q1  BasicMLP     regnet           False    0         50
# 20        NaN   UBE2Q1  BasicMLP     regnet            True    1         50
# 21   0.565598   UBE2Q1  BasicMLP     regnet           False    1         50
# 22        NaN   UBE2Q1  BasicMLP     regnet            True    2         50
# 23   0.698082   UBE2Q1  BasicMLP     regnet           False    2         50
# 24        NaN    RNF14  BasicMLP  genemania            True    0         50
# 25   0.602500    RNF14  BasicMLP  genemania           False    0         50
# 26        NaN    RNF14  BasicMLP  genemania            True    1         50
# 27   0.770505    RNF14  BasicMLP  genemania           False    1         50
# 28        NaN    RNF14  BasicMLP  genemania            True    2         50
# 29   0.802668    RNF14  BasicMLP  genemania           False    2         50
# ..        ...      ...       ...        ...             ...  ...        ...
# 603       NaN      SP1  BasicMLP  genemania            True    1         50
# 604  0.813351      SP1  BasicMLP  genemania           False    1         50
# 605       NaN      SP1  BasicMLP  genemania            True    2         50
# 606  0.797256      SP1  BasicMLP  genemania           False    2         50
# 607       NaN      SP1  BasicMLP     regnet            True    0         50
# 608  0.798869      SP1  BasicMLP     regnet           False    0         50
# 609       NaN      SP1  BasicMLP     regnet            True    1         50
# 610  0.668764      SP1  BasicMLP     regnet           False    1         50
# 611       NaN      SP1  BasicMLP     regnet            True    2         50
# 612  0.807653      SP1  BasicMLP     regnet           False    2         50
# 613       NaN      XPA  BasicMLP  genemania            True    0         50
# 614  0.565766      XPA  BasicMLP  genemania           False    0         50
# 615       NaN      XPA  BasicMLP  genemania            True    1         50
# 616  0.730081      XPA  BasicMLP  genemania           False    1         50
# 617       NaN      XPA  BasicMLP  genemania            True    2         50
# 618  0.614606      XPA  BasicMLP  genemania           False    2         50
# 619       NaN      XPA  BasicMLP     regnet            True    0         50
# 620  0.735768      XPA  BasicMLP     regnet           False    0         50
# 621       NaN      XPA  BasicMLP     regnet            True    1         50
# 622  0.703677      XPA  BasicMLP     regnet           False    1         50
# 623       NaN      XPA  BasicMLP     regnet            True    2         50
# 624  0.727959      XPA  BasicMLP     regnet           False    2         50
# 625       NaN  CEACAM6  BasicMLP  genemania            True    0         50
# 626  0.886036  CEACAM6  BasicMLP  genemania           False    0         50
# 627       NaN  CEACAM6  BasicMLP  genemania            True    1         50
# 628  0.781463  CEACAM6  BasicMLP  genemania           False    1         50
# 629       NaN  CEACAM6  BasicMLP  genemania            True    2         50
# 630  0.786461  CEACAM6  BasicMLP  genemania           False    2         50
# 631       NaN  CEACAM6  BasicMLP     regnet            True    0         50
# 632  0.913412  CEACAM6  BasicMLP     regnet           False    0         50
#
#                                 optimize_graph_results
# 0    {'KIAA0368': 0.5150952704451346, 'RNF26': 0.61...
# 1                                                 None
# 2    {'KIAA0368': 0.5278936982401656, 'RNF26': 0.57...
# 3                                                 None
# 4    {'KIAA0368': 0.4436626552795031, 'RNF26': 0.46...
# 5                                                 None
# 6    {'POLR3C': 0.7879989971532091, 'ARL3': 0.75818...
# 7                                                 None
# 8    {'POLR3C': 0.8241783126293996, 'ARL3': 0.81399...
# 9                                                 None
# 10   {'POLR3C': 0.7719170548654244, 'ARL3': 0.76577...
# 11                                                None
# 12   {'KIAA0368': 0.6017444681677019, 'RNF26': 0.53...
# 13                                                None
# 14   {'KIAA0368': 0.6059863483436854, 'RNF26': 0.55...
# 15                                                None
# 16   {'KIAA0368': 0.5973165760869565, 'RNF26': 0.61...
# 17                                                None
# 18   {'POLR3C': 0.7777036425983437, 'ARL3': 0.74042...
# 19                                                None
# 20   {'POLR3C': 0.8543445910973084, 'ARL3': 0.84673...
# 21                                                None
# 22   {'POLR3C': 0.7479215191511388, 'ARL3': 0.74928...
# 23                                                None
# 24   {'PNPLA7': 0.7812141214121412, 'HNF1A': 0.7577...
# 25                                                None
# 26   {'PNPLA7': 0.7991919191919191, 'HNF1A': 0.7733...
# 27                                                None
# 28   {'PNPLA7': 0.7311531153115312, 'HNF1A': 0.7907...
# 29                                                None
# ..                                                 ...
# 603  {'SP1': 0.8300602262390857, 'DNMT1': 0.8191489...
# 604                                               None
# 605  {'SP1': 0.8211685413068655, 'DNMT1': 0.8196178...
# 606                                               None
# 607  {'SP1': 0.7014693920075012, 'KMT2D': 0.7148449...
# 608                                               None
# 609  {'SP1': 0.7514455499501119, 'KMT2D': 0.7912237...
# 610                                               None
# 611  {'SP1': 0.7045067499068356, 'KMT2D': 0.7241493...
# 612                                               None
# 613  {'RPA2': 0.7003433977971312, 'XPO1': 0.7200267...
# 614                                               None
# 615  {'RPA2': 0.6735999935963114, 'XPO1': 0.7270067...
# 616                                               None
# 617  {'RPA2': 0.7527896068135245, 'XPO1': 0.7416151...
# 618                                               None
# 619  {'ZBTB18': 0.6401127049180328, 'ZFX': 0.527896...
# 620                                               None
# 621  {'ZBTB18': 0.7516649590163935, 'ZFX': 0.707639...
# 622                                               None
# 623  {'ZBTB18': 0.6699899141905739, 'ZFX': 0.688496...
# 624                                               None
# 625  {'CEACAM6': 0.9319973889816628, 'CEACAM7': 0.9...
# 626                                               None
# 627  {'CEACAM6': 0.9235075747564185, 'CEACAM7': 0.9...
# 628                                               None
# 629  {'CEACAM6': 0.9426376891686791, 'CEACAM7': 0.9...
# 630                                               None
# 631  {'PSG11': 0.8772661196342971, 'SEPP1': 0.87537...
# 632                                               None
#
# [633 rows x 8 columns]

# %%
results["max_auc"] = ""
for idx, result in results[results["is_first_degree"]][results["graph"] == "genemania"].iterrows():
    max_auc = 0
    gene_to_record = result["gene"]
    for gene, auc in result["optimize_graph_results"].items():
        if auc > max_auc:
            max_auc = auc
            gene_to_record = gene
        if gene == result["gene"]:
            results.at[idx, 'auc'] = auc
    results.at[idx, 'gene_to_record'] = gene_to_record
    results.at[idx, 'max_auc'] = max_auc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-98ebb7a1c9d3> in <module>
# ----> 1 results["max_auc"] = ""
#       2 for idx, result in results[results["is_first_degree"]][results["graph"] == "genemania"].iterrows():
#       3     max_auc = 0
#       4     gene_to_record = result["gene"]
#       5     for gene, auc in result["optimize_graph_results"].items():
#
# NameError: name 'results' is not defined

# %%
res = defaultdict(list)
for i, result in results[results.gene == "UBE2Q1"][results.is_first_degree][results["graph"] == "regnet"].iterrows():# [results["graph"] == "genemania"]:
    for gene, auc in result["optimize_graph_results"].items():
        res[gene].append(auc)
# Out:
# /Users/martinweiss/code/academic/conv-graph/venv/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
means = {}
variances = {}
for gene, vals in res.items():
    means[gene] = mean(vals)
    variances[gene] = np.var(vals)

# %%
for gene, values in res.items():
    res[gene] = np.array(values)

# %%
sorted_x = sorted(means.items(), key=operator.itemgetter(1))

# %%
means["PSMA2"]
# Out:
# 0.8138737248749137

# %%
mean_values = [x[1] for x in sorted_x]
mean_keys = [x[0] for x in sorted_x]

# %%
genes = list(variances.keys())

# %%
regnet = RegNetGraph()

# %%
adj = regnet.nx_graph["UBE2Q1"]

# %%
adj = np.asarray(nx.to_numpy_matrix(regnet.nx_graph))

# %%
adj[0]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
nx.to_numpy_matrix(regnet.nx_graph)["UBE2Q1"]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-155-6284d5ee081c> in <module>
# ----> 1 nx.to_numpy_matrix(regnet.nx_graph)["UBE2Q1"]
#
# ~/code/academic/conv-graph/venv/lib/python3.5/site-packages/numpy/matrixlib/defmatrix.py in __getitem__(self, index)
#     188
#     189         try:
# --> 190             out = N.ndarray.__getitem__(self, index)
#     191         finally:
#     192             self._getitem = False
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
nodes = regnet.nx_graph.edges(genes, data="weight")

# %%
bins = np.array([round(x, 1) for x in np.arange(0., 1., 0.1)])
regnet_results, regnet_labels, nodes = bucket_weights(adj, bins)
# Out:
# > <ipython-input-151-629dd2b6bdcd>(13)bucket_weights()
# -> subgraph = ((adj > x) & (adj <= x + 0.1))
# (Pdb)  x
# 0.0
# (Pdb)  adj
# AtlasView(OrderedDict([('SNRPE', OrderedDict([('weight', 0.00989999994635582)])), ('PPP4C', OrderedDict([('weight', 0.00989999994635582)])), ('C16orf71', OrderedDict([('weight', 0.01600000075995922)])), ('ARAF', OrderedDict([('weight', 0.01600000075995922)])), ('ATP5G3', OrderedDict([('weight', 0.009999999776482582)])), ('POLB', OrderedDict([('weight', 0.014000000432133675)])), ('SUN1', OrderedDict([('weight', 0.014000000432133675)])), ('NCBP2', OrderedDict([('weight', 0.01600000075995922)])), ('TADA1', OrderedDict([('weight', 0.014000000432133675)])), ('TPR', OrderedDict([('weight', 0.01600000075995922)])), ('SDHC', OrderedDict([('weight', 0.009999999776482582)])), ('GLRX2', OrderedDict([('weight', 0.014999999664723873)])), ('VPS41', OrderedDict([('weight', 0.019999999552965164)])), ('UBL4A', OrderedDict([('weight', 0.01899999938905239)])), ('HAX1', OrderedDict([('weight', 0.012000000104308128)])), ('PHB2', OrderedDict([('weight', 0.006899999920278788)])), ('SCAND1', OrderedDict([('weight', 0.013000000268220901)])), ('TRA2B', OrderedDict([('weight', 0.007600000128149986)])), ('PSMA2', OrderedDict([('weight', 0.005900000222027302)])), ('MLF2', OrderedDict([('weight', 0.014000000432133675)])), ('PCBP1', OrderedDict([('weight', 0.013000000268220901)])), ('SNRPF', OrderedDict([('weight', 0.012000000104308128)])), ('QARS', OrderedDict([('weight', 0.013000000268220901)])), ('POM121', OrderedDict([('weight', 0.010999999940395355)])), ('RNPEP', OrderedDict([('weight', 0.014000000432133675)])), ('SCAMP3', OrderedDict([('weight', 0.014999999664723873)])), ('HDGF', OrderedDict([('weight', 0.01600000075995922)])), ('MRPS21', OrderedDict([('weight', 0.014999999664723873)])), ('PRSS2', OrderedDict([('weight', 0.02199999988079071)])), ('UBE2D2', OrderedDict([('weight', 0.012000000104308128)])), ('TFB2M', OrderedDict([('weight', 0.012000000104308128)])), ('YY1AP1', OrderedDict([('weight', 0.012000000104308128)])), ('POLD2', OrderedDict([('weight', 0.006500000134110451)])), ('NCSTN', OrderedDict([('weight', 0.014999999664723873)])), ('CKS1B', OrderedDict([('weight', 0.008799999952316284)])), ('PI4KB', OrderedDict([('weight', 0.014999999664723873)])), ('IKBKE', OrderedDict([('weight', 0.013000000268220901)])), ('FAM136A', OrderedDict([('weight', 0.006899999920278788)])), ('DDX19A', OrderedDict([('weight', 0.017000000923871994)])), ('CUL4A', OrderedDict([('weight', 0.017000000923871994)])), ('HNRNPF', OrderedDict([('weight', 0.012000000104308128)])), ('PMM2', OrderedDict([('weight', 0.013000000268220901)])), ('RNPS1', OrderedDict([('weight', 0.008700000122189522)])), ('POLR3C', OrderedDict([('weight', 0.017999999225139618)])), ('FOXM1', OrderedDict([('weight', 0.006899999920278788)])), ('MTX1', OrderedDict([('weight', 0.013000000268220901)])), ('TRAP1', OrderedDict([('weight', 0.012000000104308128)])), ('IMPA2', OrderedDict([('weight', 0.017000000923871994)])), ('GTF2I', OrderedDict([('weight', 0.01600000075995922)])), ('LMOD1', OrderedDict([('weight', 0.014000000432133675)])), ('PRCC', OrderedDict([('weight', 0.02199999988079071)])), ('JMJD4', OrderedDict([('weight', 0.01899999938905239)])), ('ARL3', OrderedDict([('weight', 0.013000000268220901)])), ('UCK2', OrderedDict([('weight', 0.014999999664723873)])), ('PRELID1', OrderedDict([('weight', 0.0066999997943639755)])), ('CACYBP', OrderedDict([('weight', 0.019999999552965164)])), ('GMPS', OrderedDict([('weight', 0.006099999882280827)])), ('SLC44A2', OrderedDict([('weight', 0.01600000075995922)])), ('RIT1', OrderedDict([('weight', 0.014999999664723873)])), ('SRSF2', OrderedDict([('weight', 0.004900000058114529)])), ('TRIM47', OrderedDict([('weight', 0.013000000268220901)])), ('MED22', OrderedDict([('weight', 0.017000000923871994)]))]))
# (Pdb)  l
#   8
#   9  	    results = []
#  10  	    nodes = {}
#  11  	    for x in bins:
#  12  	        import pdb; pdb.set_trace()
#  13  ->	        subgraph = ((adj > x) & (adj <= x + 0.1))
#  14  	        results.append(subgraph.sum())
#  15  	        nodes[x] = subgraph
#  16  	    return results, labels, nodes
#  17
#  18
# (Pdb)  adj.to_numpy_matrix
# *** AttributeError: 'AtlasView' object has no attribute 'to_numpy_matrix'
# (Pdb)  nx.to_numpy_matrix(adj)
# *** AttributeError: 'AtlasView' object has no attribute 'is_directed'
# (Pdb)  q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-152-7fb88878ebdf> in <module>
#       1 bins = np.array([round(x, 1) for x in np.arange(0., 1., 0.1)])
# ----> 2 regnet_results, regnet_labels, nodes = bucket_weights(adj, bins)
#
# <ipython-input-151-629dd2b6bdcd> in bucket_weights(adj, bins)
#      11     for x in bins:
#      12         import pdb; pdb.set_trace()
# ---> 13         subgraph = ((adj > x) & (adj <= x + 0.1))
#      14         results.append(subgraph.sum())
#      15         nodes[x] = subgraph
#
# <ipython-input-151-629dd2b6bdcd> in bucket_weights(adj, bins)
#      11     for x in bins:
#      12         import pdb; pdb.set_trace()
# ---> 13         subgraph = ((adj > x) & (adj <= x + 0.1))
#      14         results.append(subgraph.sum())
#      15         nodes[x] = subgraph
#
# ~/.pyenv/versions/3.5.2/lib/python3.5/bdb.py in trace_dispatch(self, frame, event, arg)
#      46             return # None
#      47         if event == 'line':
# ---> 48             return self.dispatch_line(frame)
#      49         if event == 'call':
#      50             return self.dispatch_call(frame, arg)
#
# ~/.pyenv/versions/3.5.2/lib/python3.5/bdb.py in dispatch_line(self, frame)
#      65         if self.stop_here(frame) or self.break_here(frame):
#      66             self.user_line(frame)
# ---> 67             if self.quitting: raise BdbQuit
#      68         return self.trace_dispatch
#      69
#
# BdbQuit:

# %%
plt.figure(figsize=(9, 9))

plt.bar(x=regnet_labels, height=regnet_results)
plt.title("(Log) Histogram of Edge Weights")
plt.xlabel("Value of Edge Weights")
plt.ylabel("Number of Edges in Bucket")
plt.xlim=1.0

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-3d523c99b34e> in <module>
#       1 plt.figure(figsize=(9, 9))
#       2
# ----> 3 plt.bar(x=regnet_labels, height=regnet_results)
#       4 plt.title("(Log) Histogram of Edge Weights")
#       5 plt.xlabel("Value of Edge Weights")
#
# NameError: name 'regnet_labels' is not defined

# %%
max_edge_weight = {}
i=0
for b in bins:
    for node1, node2 in np.argwhere(nodes[b]):
        max_edge_weight[node1] = int(10 * b)
        max_edge_weight[node2] = int(10 * b)
edge_colors = list((np.round(one_gene_adj[adj.nonzero()].flatten(), 1) * 10).astype(int))[::2]
nx.draw(G, node_color=list(max_edge_weight.values()), edge_color=edge_colors, with_labels=True)
print("Clustered by max edge weight")


# Make the chart
bins = np.array([round(x, 1) for x in np.arange(0., 1., 0.1)])
one_gene_results, one_gene_labels, nodes = bucket_weights(one_gene_adj, bins)
plt.figure(figsize=(9, 9))
plt.bar(x=one_gene_labels, height=one_gene_results)
plt.title("Histogram of Edge Weights for a BFS Resulting in 50 genes near TERT")
plt.xlabel("Value of Edge Weight")
plt.ylabel("Number of Edges in Bucket")
plt.xticks(bins*10, labels=one_gene_labels[1:])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-545884446d0f> in <module>
#       1 max_edge_weight = {}
#       2 i=0
# ----> 3 for b in bins:
#       4     for node1, node2 in np.argwhere(nodes[b]):
#       5         max_edge_weight[node1] = int(10 * b)
#
# NameError: name 'bins' is not defined

# %%
plt.scatter(y=mean_values[::2], x=mean_keys[::2])
axes = plt.gca()
plt.errorbar(y=list(variances.values())[::2], x=mean_keys[::2])
plt.xticks(rotation=70)
axes.set_ylim((0.75, 0.85))
# Out:
# (0.75, 0.85)

# %%
perf = sorted(means.items(), key=operator.itemgetter(1), reverse=True)
genes = [item for item, value in perf]
print(genes)
# Out:
# ['IRF2BPL', 'USP11', 'UBE2Q1', 'STUB1', 'SNW1', 'LYPD3', 'C1QTNF2', 'RNF7', 'RNF26', 'KIAA0368', 'TCEAL1', 'UBC', 'TP53', 'FHL3', 'EXOSC7']

# %%
neighbors = list(gene_graph.first_degree(gene)[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a1304fc9701e> in <module>
# ----> 1 neighbors = list(gene_graph.first_degree(gene)[0])
#
# NameError: name 'gene_graph' is not defined

# %%
neighbors
# Out:
# ['STUB1',
#  'TCEAL1',
#  'USP11',
#  'TP53',
#  'KIAA0368',
#  'EXOSC7',
#  'RNF26',
#  'UBE2Q1',
#  'UBC',
#  'FHL3',
#  'RNF7',
#  'SNW1',
#  'LYPD3',
#  'IRF2BPL',
#  'C1QTNF2']
