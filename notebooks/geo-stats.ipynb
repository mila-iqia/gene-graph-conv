# %%
import os
os.chdir('..')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Out:
# '/Users/martinweiss/code/conv-graph/notebooks'

# %%
rnaseq = pd.read_csv("data/datasets/geo/hts-geo-series-human.csv")
rnaseq["Capture Type"] = "RNA-Seq"
microarray = pd.read_csv("data/datasets/geo/array-geo-series-human.csv")
microarray["Capture Type"] = "MicroArray"
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-31-92bcb6a0bafc> in <module>()
# ----> 1 rnaseq = pd.read_csv("data/datasets/geo/hts-geo-series-human.csv")
#       2 rnaseq["Capture Type"] = "RNA-Seq"
#       3 microarray = pd.read_csv("data/datasets/geo/array-geo-series-human.csv")
#       4 microarray["Capture Type"] = "MicroArray"
#
# /Users/martinweiss/.pyenv/versions/2.7.13/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# /Users/martinweiss/.pyenv/versions/2.7.13/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# /Users/martinweiss/.pyenv/versions/2.7.13/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# /Users/martinweiss/.pyenv/versions/2.7.13/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# /Users/martinweiss/.pyenv/versions/2.7.13/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: File data/datasets/geo/hts-geo-series-human.csv does not exist

# %%
d = microarray.append(rnaseq)

# %%
d["Release Date"] = pd.to_datetime(d["Release Date"])
d["Year"] = d["Release Date"].dt.year

# %%
d = d[d["Year"] > 2001]
d = d[d["Year"] < 2018]

# %%
#d = d[d["Sample Count"] < 500]

# %%
d["Title"] = d["Title"].str.lower()
singlecell = d["Title"].str.contains("single-cell")
singlecell |= d["Title"].str.contains("single cell")
singlecell.sum()
# Out:
# 195

# %%
d["Isolation"] = ["Single Cell" if x else "Multi Cell" for x in singlecell]

# %%
dsc = d[singlecell]
dmc = d[singlecell == False]

# %%
# dmc["Sample Count"].max()

# %%
# np.where(dmc["Sample Count"] == 878)

# %%
# dmc.iloc[1189]

# %%
r = dmc.groupby(["Year", "Capture Type"])["Sample Count"].median().unstack("Capture Type")
r
# Out:
# Capture Type  MicroArray  RNA-Seq
# Year
# 2002                 5.0      NaN
# 2003                 7.0      NaN
# 2004                18.0      NaN
# 2005                20.0      NaN
# 2006                19.0      NaN
# 2007                17.0      NaN
# 2008                15.0     18.0
# 2009                16.0      4.0
# 2010                15.0     14.0
# 2011                16.0     10.0
# 2012                15.0     10.0
# 2013                14.0      9.0
# 2014                14.0     11.0
# 2015                15.0     12.0
# 2016                12.0      2.0
# 2017                12.0     12.0

# %%
#r = d.groupby([d["Release Date"].dt.year, "capture"])["Sample Count"].mean()

# %% [markdown]
# ax = r.plot.bar(width=.66);
# ax.set_ylabel("Median size of dataset (samples)");
# ax.set_xlabel("Year of deposit into NIH GEO");

# %%
r = dmc.groupby(["Year", "Capture Type"])["Sample Count"].count().unstack("Capture Type")
r
# Out:
# Capture Type  MicroArray  RNA-Seq
# Year
# 2002                27.0      NaN
# 2003               178.0      NaN
# 2004               250.0      NaN
# 2005               399.0      NaN
# 2006               522.0      NaN
# 2007               687.0      NaN
# 2008               935.0      6.0
# 2009              1185.0      7.0
# 2010              1471.0     37.0
# 2011              1863.0     91.0
# 2012              2043.0    161.0
# 2013              2208.0    282.0
# 2014              2262.0    559.0
# 2015              2482.0    697.0
# 2016              2173.0   2183.0
# 2017              2061.0   1681.0

# %%
ax = r.plot.bar(stacked=False, width=.66);
ax.set_ylabel("Number of datasets deposited");
ax.set_xlabel("Year of deposit into NIH GEO");

# %%
r = dmc.groupby(["Year", "Capture Type"])["Sample Count"].sum().unstack("Capture Type")
r
# Out:
# Capture Type  MicroArray  RNA-Seq
# Year
# 2002               639.0      NaN
# 2003              3665.0      NaN
# 2004              8703.0      NaN
# 2005             17357.0      NaN
# 2006             23614.0      NaN
# 2007             28743.0      NaN
# 2008             37238.0    191.0
# 2009             51119.0   1453.0
# 2010             65338.0   1792.0
# 2011             81473.0   1753.0
# 2012             85445.0   2696.0
# 2013             96496.0   4855.0
# 2014            105159.0  21639.0
# 2015            109783.0  22001.0
# 2016            104131.0  41194.0
# 2017             82084.0  53021.0

# %%
ax = r.plot.bar(stacked=False);
ax.set_ylabel("Number of datasets");
ax.set_xlabel("Year of deposit into NIH GEO");

# %%
stats = d.groupby(d["Release Date"].dt.year)["Sample Count"].count()

# %%
stats.index
# Out:
# Int64Index([2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012,
#             2013, 2014, 2015, 2016, 2017],
#            dtype='int64', name=u'Release Date')

# %%
rects2 = plt.bar(stats.index, stats.as_matrix(), 1, color='red')

# %%
plt.plot(np.sort(d["Sample Count"]))

# %%
d["Sample Count"].mean()
# Out:
# 42.657534246575345

# %%
d = pd.read_csv("../data/datasets/geo/array-geo-series-human.csv")

# %%
plt.plot(np.sort(d["Sample Count"]))

# %%
d["Sample Count"].mean()
# Out:
# 43.39351742955262

# %%
d["Sample Count"].shape
# Out:
# (21257,)
